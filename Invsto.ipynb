# %% [markdown]
# <a href="https://colab.research.google.com/github/petrosbeyene/RSI-Strategies-Analysis/blob/main/Invsto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Retrieval:
# Retrieve the dataset from the Google Sheets link, and Leverage the Pandas library to efficiently read and import the data directly from Google Sheets into the project environment.

# %%
import pandas as pd
import unittest
import plotly.express as px
from sqlalchemy import create_engine, text
from sqlalchemy.orm import sessionmaker
import os

# %%
googleSheetId = '1-rIkEb94tZ69FvsjXnfkVETYu6rftF-8'
worksheetName = 'HINDALCO'

URL = 'https://docs.google.com/spreadsheets/d/{0}/gviz/tq?tqx=out:csv&sheet={1}'.format(
	googleSheetId,
	worksheetName
)

df = pd.read_csv(URL)

# Covert datetime column to datetime datatype
df['datetime'] = pd.to_datetime(df['datetime'])

df
# Out:
#        datetime   close    high     low    open   volume instrument
# 0    2014-01-24  114.00  115.35  113.00  113.15  5737135   HINDALCO
# 1    2014-01-27  111.10  112.70  109.30  112.00  8724577   HINDALCO
# 2    2014-01-28  113.80  115.00  109.75  110.00  4513345   HINDALCO
# 3    2014-01-29  111.75  114.75  111.15  114.50  4713458   HINDALCO
# 4    2014-01-30  108.10  110.70  107.60  110.20  5077231   HINDALCO
# ...         ...     ...     ...     ...     ...      ...        ...
# 1210 2018-12-21  224.00  227.45  221.80  224.25  6933691   HINDALCO
# 1211 2018-12-24  217.85  224.00  216.95  224.00  4667022   HINDALCO
# 1212 2018-12-26  218.60  219.80  212.90  213.85  6554865   HINDALCO
# 1213 2018-12-27  220.60  223.90  219.60  221.40  7947144   HINDALCO
# 1214 2018-12-28  223.50  226.05  221.00  221.00  5074920   HINDALCO
#
# [1215 rows x 7 columns]

# %% [markdown]
# # Data Validation Unit Tests
#
# This Python script contains a set of unit tests implemented using the unittest module to validate the integrity and correctness of the data within a DataFrame (df). These tests focus on ensuring that the data adheres to specific criteria related to data types and formats.
#
#
# 1. ***test_decimal_values:*** Verifies that the 'Open', 'High', 'Low', and 'Close' columns in the DataFrame contain decimal values (specifically of type 'float64').
# 2. ***test_integer_volume:*** Checks whether the 'Volume' column in the DataFrame contains integer values (of type 'int64').
# 3. ***test_string_instrument:*** Ensures that the 'Instrument' column in the DataFrame contains string values (of type 'object' in Pandas, representing strings).
# 4. ***test_datetime_datetime:*** Validates that the 'datetime' column in the DataFrame is of datetime type and adheres to the expected format.

# %%
class TestDataValidation(unittest.TestCase):
    def test_decimal_values(self):
        # Check if Open, High, Low, and Close are decimals
        self.assertTrue(df['open'].dtype == 'float64')
        self.assertTrue(df['high'].dtype == 'float64')
        self.assertTrue(df['low'].dtype == 'float64')
        self.assertTrue(df['close'].dtype == 'float64')

    def test_integer_volume(self):
        # Check if Volume is an integer
        self.assertTrue(df['volume'].dtype == 'int64')

    def test_string_instrument(self):
        # Check if Instrument is a string
        self.assertTrue(df['instrument'].dtype == 'object')  # 'object' represents strings in Pandas

    def test_datetime_datetime(self):
        # Check if 'datetime' is a datetime object with the expected format
        self.assertTrue(pd.api.types.is_datetime64_dtype(df['datetime']))


if __name__ == '__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# ....
# ----------------------------------------------------------------------
# Ran 4 tests in 0.008s
#
# OK

# %% [markdown]
# # Setup PostgeSQL Database
# This step involves the installation and configuration of a PostgreSQL database for the project. It includes updating package information, installing PostgreSQL, starting the PostgreSQL service, setting a password for the default user (postgres), and creating a new database named invsto_db.

# %%
#We can use %%capture at the start of the cell to hide output of the installation
# %%capture
# Install postgresql server
# !sudo apt-get -y -qq update
# !sudo apt-get -y -qq install postgresql
# !sudo service postgresql start
# Setup a password `postgres` for username `postgres`
# !sudo -u postgres psql -U postgres -c "ALTER USER postgres PASSWORD 'postgres';"
# Setup a database with name `sampledb` to be used
# !sudo -u postgres psql -U postgres -c 'DROP DATABASE IF EXISTS invsto_db;'
# !sudo -u postgres psql -U postgres -c 'CREATE DATABASE invsto_db;'

# %%
# set connection
# %env DATABASE_URL=postgresql://postgres:postgres@localhost:5432/invsto_db
# Out:
# env: DATABASE_URL=postgresql://postgres:postgres@localhost:5432/invsto_db

# %%
# load the sql extention to start using %%sql
# %load_ext sql

# %% [markdown]
# # Establishing a Table for Data Storage

# %%
# %%sql
# CREATE TABLE stock_data (
#     id SERIAL PRIMARY KEY,
#     open DECIMAL,
#     high DECIMAL,
#     low DECIMAL,
#     close DECIMAL,
#     volume INT,
#     instrument VARCHAR(255),
#     datetime TIMESTAMP
# );
# Out:
# Done.
# []

# %% [markdown]
# # Python-Powered Database Insertion Process
#
# Using SQLAlchemy, establish a connection to the database with a provided URL. Employ a session for efficient transaction management. Utilize Pandas to convert the DataFrame to a list of dictionaries for swift data insertion. Execute a bulk insert operation into the designated table using a prepared SQL query, committing changes to the database. In case of exceptions, rollback for data integrity is handled automatically.

# %%
# Create a SQLAlchemy engine to connect to your database
database_url = os.getenv('DATABASE_URL')

engine = create_engine(database_url)

# Create a session
Session = sessionmaker(bind=engine)

# Use a context manager for the session
with Session() as session:
    try:
        # If your DataFrame and database table have matching data types, you can use the "to_dict" method for efficiency
        data_list = df.to_dict(orient='records')

        # Create a text object for your SQL query
        sql_query = text("INSERT INTO stock_data (open, high, low, close, volume, instrument, datetime) "
                         "VALUES (:open, :high, :low, :close, :volume, :instrument, :datetime)")

        # Bulk insert data
        session.execute(sql_query, data_list)

        # Commit the changes
        session.commit()
    except Exception as e:
        session.rollback()  # Rollback changes if an exception occurs
        print(f"Error: {e}")

# %%
# %%sql
# select * from stock_data
# Out:
#  * postgresql://postgres:***@localhost:5432/invsto_db
# 1215 rows affected.
# [(1, Decimal('113.15'), Decimal('115.35'), Decimal('113.0'), Decimal('114.0'), 5737135, 'HINDALCO', datetime.datetime(2014, 1, 24, 0, 0)),
#  (2, Decimal('112.0'), Decimal('112.7'), Decimal('109.3'), Decimal('111.1'), 8724577, 'HINDALCO', datetime.datetime(2014, 1, 27, 0, 0)),
#  (3, Decimal('110.0'), Decimal('115.0'), Decimal('109.75'), Decimal('113.8'), 4513345, 'HINDALCO', datetime.datetime(2014, 1, 28, 0, 0)),
#  (4, Decimal('114.5'), Decimal('114.75'), Decimal('111.15'), Decimal('111.75'), 4713458, 'HINDALCO', datetime.datetime(2014, 1, 29, 0, 0)),
#  (5, Decimal('110.2'), Decimal('110.7'), Decimal('107.6'), Decimal('108.1'), 5077231, 'HINDALCO', datetime.datetime(2014, 1, 30, 0, 0)),
#  (6, Decimal('109.05'), Decimal('110.0'), Decimal('107.0'), Decimal('109.55'), 8287236, 'HINDALCO', datetime.datetime(2014, 1, 31, 0, 0)),
#  (7, Decimal('109.0'), Decimal('109.4'), Decimal('103.0'), Decimal('103.45'), 5572627, 'HINDALCO', datetime.datetime(2014, 2, 3, 0, 0)),
#  (8, Decimal('102.0'), Decimal('103.45'), Decimal('99.8'), Decimal('102.45'), 13935173, 'HINDALCO', datetime.datetime(2014, 2, 4, 0, 0)),
#  (9, Decimal('102.4'), Decimal('105.15'), Decimal('101.0'), Decimal('104.25'), 9106760, 'HINDALCO', datetime.datetime(2014, 2, 5, 0, 0)),
#  (10, Decimal('104.65'), Decimal('106.5'), Decimal('103.1'), Decimal('105.75'), 10194884, 'HINDALCO', datetime.datetime(2014, 2, 6, 0, 0)),
#  (11, Decimal('106.15'), Decimal('107.7'), Decimal('104.75'), Decimal('106.4'), 9650511, 'HINDALCO', datetime.datetime(2014, 2, 7, 0, 0)),
#  (12, Decimal('106.45'), Decimal('107.7'), Decimal('105.8'), Decimal('106.8'), 3124538, 'HINDALCO', datetime.datetime(2014, 2, 10, 0, 0)),
#  (13, Decimal('106.9'), Decimal('107.1'), Decimal('104.25'), Decimal('104.55'), 3964390, 'HINDALCO', datetime.datetime(2014, 2, 11, 0, 0)),
#  (14, Decimal('105.15'), Decimal('105.6'), Decimal('103.05'), Decimal('103.5'), 5325176, 'HINDALCO', datetime.datetime(2014, 2, 12, 0, 0)),
#  (15, Decimal('103.9'), Decimal('104.55'), Decimal('99.75'), Decimal('100.2'), 12652556, 'HINDALCO', datetime.datetime(2014, 2, 13, 0, 0)),
#  (16, Decimal('100.75'), Decimal('101.0'), Decimal('97.85'), Decimal('99.9'), 6390793, 'HINDALCO', datetime.datetime(2014, 2, 14, 0, 0)),
#  (17, Decimal('100.0'), Decimal('100.75'), Decimal('97.65'), Decimal('98.5'), 6870442, 'HINDALCO', datetime.datetime(2014, 2, 17, 0, 0)),
#  (18, Decimal('98.7'), Decimal('100.5'), Decimal('97.75'), Decimal('99.3'), 8475360, 'HINDALCO', datetime.datetime(2014, 2, 18, 0, 0)),
#  (19, Decimal('99.6'), Decimal('100.1'), Decimal('98.4'), Decimal('98.85'), 4582897, 'HINDALCO', datetime.datetime(2014, 2, 19, 0, 0)),
#  (20, Decimal('98.5'), Decimal('98.55'), Decimal('97.05'), Decimal('97.35'), 3404267, 'HINDALCO', datetime.datetime(2014, 2, 20, 0, 0)),
#  (21, Decimal('97.3'), Decimal('98.25'), Decimal('97.3'), Decimal('97.65'), 6484994, 'HINDALCO', datetime.datetime(2014, 2, 21, 0, 0)),
#  (22, Decimal('97.65'), Decimal('98.8'), Decimal('96.7'), Decimal('97.45'), 8047904, 'HINDALCO', datetime.datetime(2014, 2, 24, 0, 0)),
#  (23, Decimal('97.15'), Decimal('99.05'), Decimal('97.0'), Decimal('98.8'), 15034041, 'HINDALCO', datetime.datetime(2014, 2, 25, 0, 0)),
#  (24, Decimal('99.75'), Decimal('99.75'), Decimal('98.05'), Decimal('98.4'), 12130348, 'HINDALCO', datetime.datetime(2014, 2, 26, 0, 0)),
#  (25, Decimal('99.0'), Decimal('106.4'), Decimal('99.0'), Decimal('105.35'), 26493472, 'HINDALCO', datetime.datetime(2014, 2, 28, 0, 0)),
#  (26, Decimal('105.0'), Decimal('107.35'), Decimal('104.7'), Decimal('105.6'), 9870841, 'HINDALCO', datetime.datetime(2014, 3, 3, 0, 0)),
#  (27, Decimal('105.4'), Decimal('114.25'), Decimal('105.4'), Decimal('113.6'), 16427565, 'HINDALCO', datetime.datetime(2014, 3, 4, 0, 0)),
#  (28, Decimal('114.85'), Decimal('117.2'), Decimal('112.2'), Decimal('115.75'), 12023136, 'HINDALCO', datetime.datetime(2014, 3, 5, 0, 0)),
#  (29, Decimal('115.75'), Decimal('121.2'), Decimal('114.7'), Decimal('120.8'), 16609108, 'HINDALCO', datetime.datetime(2014, 3, 6, 0, 0)),
#  (30, Decimal('120.1'), Decimal('125.85'), Decimal('119.8'), Decimal('124.55'), 15695038, 'HINDALCO', datetime.datetime(2014, 3, 7, 0, 0)),
#  (31, Decimal('123.05'), Decimal('123.5'), Decimal('121.0'), Decimal('121.95'), 8823020, 'HINDALCO', datetime.datetime(2014, 3, 10, 0, 0)),
#  (32, Decimal('121.9'), Decimal('121.9'), Decimal('116.2'), Decimal('117.4'), 14421017, 'HINDALCO', datetime.datetime(2014, 3, 11, 0, 0)),
#  (33, Decimal('115.7'), Decimal('118.4'), Decimal('113.95'), Decimal('114.75'), 9497798, 'HINDALCO', datetime.datetime(2014, 3, 12, 0, 0)),
#  (34, Decimal('114.5'), Decimal('118.95'), Decimal('114.5'), Decimal('115.65'), 6402750, 'HINDALCO', datetime.datetime(2014, 3, 13, 0, 0)),
#  (35, Decimal('114.7'), Decimal('116.1'), Decimal('113.5'), Decimal('115.2'), 5684021, 'HINDALCO', datetime.datetime(2014, 3, 14, 0, 0)),
#  (36, Decimal('116.0'), Decimal('116.4'), Decimal('114.2'), Decimal('114.85'), 8034386, 'HINDALCO', datetime.datetime(2014, 3, 18, 0, 0)),
#  (37, Decimal('115.25'), Decimal('121.1'), Decimal('114.05'), Decimal('120.05'), 15915307, 'HINDALCO', datetime.datetime(2014, 3, 19, 0, 0)),
#  (38, Decimal('119.65'), Decimal('121.95'), Decimal('119.0'), Decimal('119.65'), 7021283, 'HINDALCO', datetime.datetime(2014, 3, 20, 0, 0)),
#  (39, Decimal('120.55'), Decimal('124.0'), Decimal('119.8'), Decimal('123.5'), 10588714, 'HINDALCO', datetime.datetime(2014, 3, 21, 0, 0)),
#  (40, Decimal('123.15'), Decimal('123.15'), Decimal('120.75'), Decimal('121.2'), 652207, 'HINDALCO', datetime.datetime(2014, 3, 22, 0, 0)),
#  (41, Decimal('120.0'), Decimal('122.5'), Decimal('118.2'), Decimal('121.6'), 7514958, 'HINDALCO', datetime.datetime(2014, 3, 24, 0, 0)),
#  (42, Decimal('120.95'), Decimal('122.65'), Decimal('120.25'), Decimal('120.75'), 8547719, 'HINDALCO', datetime.datetime(2014, 3, 25, 0, 0)),
#  (43, Decimal('121.1'), Decimal('125.95'), Decimal('121.1'), Decimal('125.4'), 14059505, 'HINDALCO', datetime.datetime(2014, 3, 26, 0, 0)),
#  (44, Decimal('125.2'), Decimal('126.45'), Decimal('124.05'), Decimal('125.4'), 6763076, 'HINDALCO', datetime.datetime(2014, 3, 27, 0, 0)),
#  (45, Decimal('125.4'), Decimal('131.7'), Decimal('125.0'), Decimal('130.9'), 9719662, 'HINDALCO', datetime.datetime(2014, 3, 28, 0, 0)),
#  (46, Decimal('132.0'), Decimal('142.95'), Decimal('131.05'), Decimal('141.75'), 27873616, 'HINDALCO', datetime.datetime(2014, 3, 31, 0, 0)),
#  (47, Decimal('142.0'), Decimal('142.5'), Decimal('136.1'), Decimal('138.2'), 12584698, 'HINDALCO', datetime.datetime(2014, 4, 1, 0, 0)),
#  (48, Decimal('139.0'), Decimal('139.55'), Decimal('134.6'), Decimal('136.0'), 10111996, 'HINDALCO', datetime.datetime(2014, 4, 2, 0, 0)),
#  (49, Decimal('136.0'), Decimal('140.9'), Decimal('133.3'), Decimal('137.15'), 10256995, 'HINDALCO', datetime.datetime(2014, 4, 3, 0, 0)),
#  (50, Decimal('137.9'), Decimal('139.4'), Decimal('136.1'), Decimal('137.65'), 5444146, 'HINDALCO', datetime.datetime(2014, 4, 4, 0, 0)),
#  (51, Decimal('137.5'), Decimal('138.95'), Decimal('134.2'), Decimal('137.35'), 4661247, 'HINDALCO', datetime.datetime(2014, 4, 7, 0, 0)),
#  (52, Decimal('138.0'), Decimal('143.95'), Decimal('137.8'), Decimal('142.9'), 9943888, 'HINDALCO', datetime.datetime(2014, 4, 9, 0, 0)),
#  (53, Decimal('143.5'), Decimal('145.1'), Decimal('140.6'), Decimal('142.5'), 8923225, 'HINDALCO', datetime.datetime(2014, 4, 10, 0, 0)),
#  (54, Decimal('141.1'), Decimal('143.25'), Decimal('139.2'), Decimal('140.7'), 5404598, 'HINDALCO', datetime.datetime(2014, 4, 11, 0, 0)),
#  (55, Decimal('140.7'), Decimal('142.1'), Decimal('133.2'), Decimal('134.05'), 5422799, 'HINDALCO', datetime.datetime(2014, 4, 15, 0, 0)),
#  (56, Decimal('133.3'), Decimal('137.85'), Decimal('131.6'), Decimal('135.45'), 8006291, 'HINDALCO', datetime.datetime(2014, 4, 16, 0, 0)),
#  (57, Decimal('135.75'), Decimal('142.0'), Decimal('135.0'), Decimal('141.45'), 8629888, 'HINDALCO', datetime.datetime(2014, 4, 17, 0, 0)),
#  (58, Decimal('141.8'), Decimal('144.5'), Decimal('141.5'), Decimal('143.5'), 4436455, 'HINDALCO', datetime.datetime(2014, 4, 21, 0, 0)),
#  (59, Decimal('142.0'), Decimal('147.2'), Decimal('140.3'), Decimal('144.85'), 6223989, 'HINDALCO', datetime.datetime(2014, 4, 22, 0, 0)),
#  (60, Decimal('145.0'), Decimal('146.0'), Decimal('142.8'), Decimal('145.15'), 5031335, 'HINDALCO', datetime.datetime(2014, 4, 23, 0, 0)),
#  (61, Decimal('143.3'), Decimal('146.9'), Decimal('142.2'), Decimal('143.75'), 4116077, 'HINDALCO', datetime.datetime(2014, 4, 25, 0, 0)),
#  (62, Decimal('143.0'), Decimal('145.3'), Decimal('140.8'), Decimal('141.25'), 4118525, 'HINDALCO', datetime.datetime(2014, 4, 28, 0, 0)),
#  (63, Decimal('141.0'), Decimal('143.0'), Decimal('136.3'), Decimal('137.2'), 4775590, 'HINDALCO', datetime.datetime(2014, 4, 29, 0, 0)),
#  (64, Decimal('136.65'), Decimal('138.85'), Decimal('132.05'), Decimal('134.3'), 7609347, 'HINDALCO', datetime.datetime(2014, 4, 30, 0, 0)),
#  (65, Decimal('135.2'), Decimal('136.0'), Decimal('130.25'), Decimal('131.65'), 5364611, 'HINDALCO', datetime.datetime(2014, 5, 2, 0, 0)),
#  (66, Decimal('130.0'), Decimal('141.0'), Decimal('129.85'), Decimal('138.9'), 9715098, 'HINDALCO', datetime.datetime(2014, 5, 5, 0, 0)),
#  (67, Decimal('139.4'), Decimal('140.65'), Decimal('135.8'), Decimal('138.7'), 4170017, 'HINDALCO', datetime.datetime(2014, 5, 6, 0, 0)),
#  (68, Decimal('138.35'), Decimal('138.65'), Decimal('134.3'), Decimal('135.2'), 3592081, 'HINDALCO', datetime.datetime(2014, 5, 7, 0, 0)),
#  (69, Decimal('136.25'), Decimal('139.1'), Decimal('135.0'), Decimal('136.75'), 4178306, 'HINDALCO', datetime.datetime(2014, 5, 8, 0, 0)),
#  (70, Decimal('136.5'), Decimal('144.7'), Decimal('136.5'), Decimal('144.1'), 7371362, 'HINDALCO', datetime.datetime(2014, 5, 9, 0, 0)),
#  (71, Decimal('143.5'), Decimal('144.8'), Decimal('140.55'), Decimal('143.4'), 8081158, 'HINDALCO', datetime.datetime(2014, 5, 12, 0, 0)),
#  (72, Decimal('144.0'), Decimal('149.8'), Decimal('141.2'), Decimal('142.2'), 16612600, 'HINDALCO', datetime.datetime(2014, 5, 13, 0, 0)),
#  (73, Decimal('142.2'), Decimal('145.8'), Decimal('140.4'), Decimal('141.2'), 12157631, 'HINDALCO', datetime.datetime(2014, 5, 14, 0, 0)),
#  (74, Decimal('142.0'), Decimal('143.45'), Decimal('137.1'), Decimal('138.5'), 6154288, 'HINDALCO', datetime.datetime(2014, 5, 15, 0, 0)),
#  (75, Decimal('141.9'), Decimal('145.95'), Decimal('139.1'), Decimal('141.2'), 13107049, 'HINDALCO', datetime.datetime(2014, 5, 16, 0, 0)),
#  (76, Decimal('142.6'), Decimal('152.95'), Decimal('142.0'), Decimal('152.05'), 13751989, 'HINDALCO', datetime.datetime(2014, 5, 19, 0, 0)),
#  (77, Decimal('155.15'), Decimal('159.0'), Decimal('152.35'), Decimal('156.2'), 9385502, 'HINDALCO', datetime.datetime(2014, 5, 20, 0, 0)),
#  (78, Decimal('156.1'), Decimal('163.65'), Decimal('152.05'), Decimal('159.7'), 13573762, 'HINDALCO', datetime.datetime(2014, 5, 21, 0, 0)),
#  (79, Decimal('161.85'), Decimal('161.85'), Decimal('154.0'), Decimal('155.1'), 12270836, 'HINDALCO', datetime.datetime(2014, 5, 22, 0, 0)),
#  (80, Decimal('156.95'), Decimal('156.95'), Decimal('149.7'), Decimal('152.05'), 19542712, 'HINDALCO', datetime.datetime(2014, 5, 23, 0, 0)),
#  (81, Decimal('155.0'), Decimal('155.2'), Decimal('143.7'), Decimal('147.1'), 12522081, 'HINDALCO', datetime.datetime(2014, 5, 26, 0, 0)),
#  (82, Decimal('147.9'), Decimal('150.5'), Decimal('141.75'), Decimal('149.65'), 13805470, 'HINDALCO', datetime.datetime(2014, 5, 27, 0, 0)),
#  (83, Decimal('149.7'), Decimal('151.55'), Decimal('146.1'), Decimal('147.2'), 11376239, 'HINDALCO', datetime.datetime(2014, 5, 28, 0, 0)),
#  (84, Decimal('146.5'), Decimal('153.2'), Decimal('143.1'), Decimal('149.3'), 19321960, 'HINDALCO', datetime.datetime(2014, 5, 29, 0, 0)),
#  (85, Decimal('151.5'), Decimal('152.5'), Decimal('147.0'), Decimal('148.0'), 11040937, 'HINDALCO', datetime.datetime(2014, 5, 30, 0, 0)),
#  (86, Decimal('147.3'), Decimal('151.15'), Decimal('146.35'), Decimal('150.05'), 13844656, 'HINDALCO', datetime.datetime(2014, 6, 2, 0, 0)),
#  (87, Decimal('150.7'), Decimal('155.7'), Decimal('149.35'), Decimal('155.2'), 23276134, 'HINDALCO', datetime.datetime(2014, 6, 3, 0, 0)),
#  (88, Decimal('156.0'), Decimal('161.75'), Decimal('155.2'), Decimal('160.7'), 15948295, 'HINDALCO', datetime.datetime(2014, 6, 4, 0, 0)),
#  (89, Decimal('160.6'), Decimal('171.0'), Decimal('159.95'), Decimal('169.85'), 20296986, 'HINDALCO', datetime.datetime(2014, 6, 5, 0, 0)),
#  (90, Decimal('172.0'), Decimal('172.1'), Decimal('165.3'), Decimal('169.25'), 13769155, 'HINDALCO', datetime.datetime(2014, 6, 6, 0, 0)),
#  (91, Decimal('169.8'), Decimal('173.65'), Decimal('167.6'), Decimal('169.6'), 10337636, 'HINDALCO', datetime.datetime(2014, 6, 9, 0, 0)),
#  (92, Decimal('169.65'), Decimal('173.35'), Decimal('162.2'), Decimal('169.75'), 13457788, 'HINDALCO', datetime.datetime(2014, 6, 10, 0, 0)),
#  (93, Decimal('170.0'), Decimal('171.5'), Decimal('161.0'), Decimal('162.65'), 11473448, 'HINDALCO', datetime.datetime(2014, 6, 11, 0, 0)),
#  (94, Decimal('162.8'), Decimal('170.0'), Decimal('162.0'), Decimal('169.25'), 13367632, 'HINDALCO', datetime.datetime(2014, 6, 12, 0, 0)),
#  (95, Decimal('169.45'), Decimal('169.45'), Decimal('158.5'), Decimal('162.35'), 11006055, 'HINDALCO', datetime.datetime(2014, 6, 13, 0, 0)),
#  (96, Decimal('161.5'), Decimal('168.25'), Decimal('158.6'), Decimal('161.2'), 10365321, 'HINDALCO', datetime.datetime(2014, 6, 16, 0, 0)),
#  (97, Decimal('161.0'), Decimal('163.7'), Decimal('157.0'), Decimal('162.65'), 9823831, 'HINDALCO', datetime.datetime(2014, 6, 17, 0, 0)),
#  (98, Decimal('161.35'), Decimal('169.6'), Decimal('161.35'), Decimal('166.8'), 14186255, 'HINDALCO', datetime.datetime(2014, 6, 18, 0, 0)),
#  (99, Decimal('167.95'), Decimal('170.7'), Decimal('164.15'), Decimal('167.75'), 14719990, 'HINDALCO', datetime.datetime(2014, 6, 19, 0, 0)),
#  (100, Decimal('167.9'), Decimal('169.8'), Decimal('163.0'), Decimal('163.8'), 8800606, 'HINDALCO', datetime.datetime(2014, 6, 20, 0, 0)),
#  (101, Decimal('163.5'), Decimal('167.4'), Decimal('163.15'), Decimal('165.3'), 8765528, 'HINDALCO', datetime.datetime(2014, 6, 23, 0, 0)),
#  (102, Decimal('166.1'), Decimal('168.35'), Decimal('165.3'), Decimal('166.8'), 6166113, 'HINDALCO', datetime.datetime(2014, 6, 24, 0, 0)),
#  (103, Decimal('167.0'), Decimal('168.0'), Decimal('165.65'), Decimal('166.7'), 4898203, 'HINDALCO', datetime.datetime(2014, 6, 25, 0, 0)),
#  (104, Decimal('166.5'), Decimal('168.25'), Decimal('164.0'), Decimal('165.25'), 7655847, 'HINDALCO', datetime.datetime(2014, 6, 26, 0, 0)),
#  (105, Decimal('165.1'), Decimal('165.3'), Decimal('160.25'), Decimal('160.9'), 6538554, 'HINDALCO', datetime.datetime(2014, 6, 27, 0, 0)),
#  (106, Decimal('160.5'), Decimal('165.3'), Decimal('160.0'), Decimal('164.2'), 5259988, 'HINDALCO', datetime.datetime(2014, 6, 30, 0, 0)),
#  (107, Decimal('167.2'), Decimal('177.2'), Decimal('167.2'), Decimal('175.25'), 18819612, 'HINDALCO', datetime.datetime(2014, 7, 1, 0, 0)),
#  (108, Decimal('177.8'), Decimal('179.15'), Decimal('174.05'), Decimal('178.25'), 11699288, 'HINDALCO', datetime.datetime(2014, 7, 2, 0, 0)),
#  (109, Decimal('178.25'), Decimal('180.75'), Decimal('172.85'), Decimal('173.75'), 12055737, 'HINDALCO', datetime.datetime(2014, 7, 3, 0, 0)),
#  (110, Decimal('171.95'), Decimal('174.55'), Decimal('171.05'), Decimal('173.25'), 6733395, 'HINDALCO', datetime.datetime(2014, 7, 4, 0, 0)),
#  (111, Decimal('173.45'), Decimal('175.85'), Decimal('172.1'), Decimal('174.5'), 7093773, 'HINDALCO', datetime.datetime(2014, 7, 7, 0, 0)),
#  (112, Decimal('174.7'), Decimal('175.9'), Decimal('168.15'), Decimal('169.0'), 6479098, 'HINDALCO', datetime.datetime(2014, 7, 8, 0, 0)),
#  (113, Decimal('168.35'), Decimal('177.6'), Decimal('167.3'), Decimal('170.55'), 11753471, 'HINDALCO', datetime.datetime(2014, 7, 9, 0, 0)),
#  (114, Decimal('172.0'), Decimal('184.9'), Decimal('168.3'), Decimal('176.25'), 13850220, 'HINDALCO', datetime.datetime(2014, 7, 10, 0, 0)),
#  (115, Decimal('176.5'), Decimal('177.65'), Decimal('165.35'), Decimal('166.75'), 9546897, 'HINDALCO', datetime.datetime(2014, 7, 11, 0, 0)),
#  (116, Decimal('165.45'), Decimal('175.0'), Decimal('165.0'), Decimal('173.4'), 7338881, 'HINDALCO', datetime.datetime(2014, 7, 14, 0, 0)),
#  (117, Decimal('175.4'), Decimal('176.4'), Decimal('167.65'), Decimal('174.7'), 8803424, 'HINDALCO', datetime.datetime(2014, 7, 15, 0, 0)),
#  (118, Decimal('176.0'), Decimal('183.3'), Decimal('174.3'), Decimal('182.3'), 10109551, 'HINDALCO', datetime.datetime(2014, 7, 16, 0, 0)),
#  (119, Decimal('183.3'), Decimal('189.5'), Decimal('180.6'), Decimal('188.65'), 11547823, 'HINDALCO', datetime.datetime(2014, 7, 17, 0, 0)),
#  (120, Decimal('187.0'), Decimal('187.15'), Decimal('183.55'), Decimal('184.6'), 9555163, 'HINDALCO', datetime.datetime(2014, 7, 18, 0, 0)),
#  (121, Decimal('185.85'), Decimal('186.0'), Decimal('179.2'), Decimal('183.85'), 12711833, 'HINDALCO', datetime.datetime(2014, 7, 21, 0, 0)),
#  (122, Decimal('184.6'), Decimal('190.0'), Decimal('183.0'), Decimal('188.25'), 12856830, 'HINDALCO', datetime.datetime(2014, 7, 22, 0, 0)),
#  (123, Decimal('189.0'), Decimal('194.5'), Decimal('189.0'), Decimal('193.75'), 16908175, 'HINDALCO', datetime.datetime(2014, 7, 23, 0, 0)),
#  (124, Decimal('194.2'), Decimal('198.9'), Decimal('192.5'), Decimal('198.0'), 14784601, 'HINDALCO', datetime.datetime(2014, 7, 24, 0, 0)),
#  (125, Decimal('198.9'), Decimal('198.9'), Decimal('190.5'), Decimal('191.8'), 14535973, 'HINDALCO', datetime.datetime(2014, 7, 25, 0, 0)),
#  (126, Decimal('191.8'), Decimal('194.4'), Decimal('186.5'), Decimal('187.8'), 7659739, 'HINDALCO', datetime.datetime(2014, 7, 28, 0, 0)),
#  (127, Decimal('188.05'), Decimal('193.8'), Decimal('186.1'), Decimal('192.6'), 10593328, 'HINDALCO', datetime.datetime(2014, 7, 30, 0, 0)),
#  (128, Decimal('193.1'), Decimal('195.0'), Decimal('188.65'), Decimal('191.7'), 13370034, 'HINDALCO', datetime.datetime(2014, 7, 31, 0, 0)),
#  (129, Decimal('189.7'), Decimal('194.7'), Decimal('183.15'), Decimal('184.3'), 12377607, 'HINDALCO', datetime.datetime(2014, 8, 1, 0, 0)),
#  (130, Decimal('184.1'), Decimal('193.15'), Decimal('184.1'), Decimal('190.9'), 9443678, 'HINDALCO', datetime.datetime(2014, 8, 4, 0, 0)),
#  (131, Decimal('191.4'), Decimal('196.6'), Decimal('189.1'), Decimal('195.65'), 10095697, 'HINDALCO', datetime.datetime(2014, 8, 5, 0, 0)),
#  (132, Decimal('194.25'), Decimal('196.7'), Decimal('190.95'), Decimal('191.75'), 6055467, 'HINDALCO', datetime.datetime(2014, 8, 6, 0, 0)),
#  (133, Decimal('192.0'), Decimal('193.35'), Decimal('188.1'), Decimal('189.1'), 7742761, 'HINDALCO', datetime.datetime(2014, 8, 7, 0, 0)),
#  (134, Decimal('186.8'), Decimal('187.2'), Decimal('180.55'), Decimal('183.95'), 9919821, 'HINDALCO', datetime.datetime(2014, 8, 8, 0, 0)),
#  (135, Decimal('185.0'), Decimal('187.9'), Decimal('184.5'), Decimal('185.65'), 4670064, 'HINDALCO', datetime.datetime(2014, 8, 11, 0, 0)),
#  (136, Decimal('187.8'), Decimal('187.8'), Decimal('183.3'), Decimal('185.4'), 7032239, 'HINDALCO', datetime.datetime(2014, 8, 12, 0, 0)),
#  (137, Decimal('184.55'), Decimal('185.45'), Decimal('177.15'), Decimal('180.05'), 7549317, 'HINDALCO', datetime.datetime(2014, 8, 13, 0, 0)),
#  (138, Decimal('180.8'), Decimal('183.45'), Decimal('175.75'), Decimal('178.6'), 14030737, 'HINDALCO', datetime.datetime(2014, 8, 14, 0, 0)),
#  (139, Decimal('176.45'), Decimal('185.25'), Decimal('176.05'), Decimal('182.25'), 9334923, 'HINDALCO', datetime.datetime(2014, 8, 18, 0, 0)),
#  (140, Decimal('182.4'), Decimal('185.65'), Decimal('179.8'), Decimal('180.85'), 10288612, 'HINDALCO', datetime.datetime(2014, 8, 19, 0, 0)),
#  (141, Decimal('180.45'), Decimal('183.0'), Decimal('179.45'), Decimal('180.35'), 10604946, 'HINDALCO', datetime.datetime(2014, 8, 20, 0, 0)),
#  (142, Decimal('179.0'), Decimal('182.35'), Decimal('176.5'), Decimal('177.9'), 7638544, 'HINDALCO', datetime.datetime(2014, 8, 21, 0, 0)),
#  (143, Decimal('178.05'), Decimal('184.15'), Decimal('178.05'), Decimal('182.5'), 8364204, 'HINDALCO', datetime.datetime(2014, 8, 22, 0, 0)),
#  (144, Decimal('183.75'), Decimal('184.7'), Decimal('160.15'), Decimal('164.85'), 18698120, 'HINDALCO', datetime.datetime(2014, 8, 25, 0, 0)),
#  (145, Decimal('159.0'), Decimal('171.6'), Decimal('157.7'), Decimal('170.5'), 22135877, 'HINDALCO', datetime.datetime(2014, 8, 26, 0, 0)),
#  (146, Decimal('171.0'), Decimal('173.3'), Decimal('168.25'), Decimal('172.3'), 9876204, 'HINDALCO', datetime.datetime(2014, 8, 27, 0, 0)),
#  (147, Decimal('171.85'), Decimal('173.8'), Decimal('169.5'), Decimal('170.1'), 6182439, 'HINDALCO', datetime.datetime(2014, 8, 28, 0, 0)),
#  (148, Decimal('171.9'), Decimal('178.95'), Decimal('169.4'), Decimal('176.15'), 11752433, 'HINDALCO', datetime.datetime(2014, 9, 1, 0, 0)),
#  (149, Decimal('176.0'), Decimal('177.5'), Decimal('173.5'), Decimal('174.85'), 7741063, 'HINDALCO', datetime.datetime(2014, 9, 2, 0, 0)),
#  (150, Decimal('174.0'), Decimal('177.25'), Decimal('173.2'), Decimal('175.1'), 8545333, 'HINDALCO', datetime.datetime(2014, 9, 3, 0, 0)),
#  (151, Decimal('173.3'), Decimal('174.95'), Decimal('165.85'), Decimal('169.5'), 6861332, 'HINDALCO', datetime.datetime(2014, 9, 4, 0, 0)),
#  (152, Decimal('168.55'), Decimal('172.45'), Decimal('166.05'), Decimal('167.7'), 5787423, 'HINDALCO', datetime.datetime(2014, 9, 5, 0, 0)),
#  (153, Decimal('168.1'), Decimal('174.0'), Decimal('168.1'), Decimal('173.45'), 8514685, 'HINDALCO', datetime.datetime(2014, 9, 8, 0, 0)),
#  (154, Decimal('172.5'), Decimal('174.95'), Decimal('169.35'), Decimal('172.9'), 7951226, 'HINDALCO', datetime.datetime(2014, 9, 9, 0, 0)),
#  (155, Decimal('170.6'), Decimal('174.9'), Decimal('170.1'), Decimal('172.9'), 4651282, 'HINDALCO', datetime.datetime(2014, 9, 10, 0, 0)),
#  (156, Decimal('172.05'), Decimal('175.45'), Decimal('171.7'), Decimal('173.0'), 4690133, 'HINDALCO', datetime.datetime(2014, 9, 11, 0, 0)),
#  (157, Decimal('173.0'), Decimal('173.45'), Decimal('167.1'), Decimal('168.6'), 6512210, 'HINDALCO', datetime.datetime(2014, 9, 12, 0, 0)),
#  (158, Decimal('167.95'), Decimal('168.75'), Decimal('162.95'), Decimal('163.6'), 8421482, 'HINDALCO', datetime.datetime(2014, 9, 15, 0, 0)),
#  (159, Decimal('162.0'), Decimal('165.95'), Decimal('160.0'), Decimal('160.35'), 8528462, 'HINDALCO', datetime.datetime(2014, 9, 16, 0, 0)),
#  (160, Decimal('162.05'), Decimal('163.3'), Decimal('157.0'), Decimal('160.65'), 7797094, 'HINDALCO', datetime.datetime(2014, 9, 17, 0, 0)),
#  (161, Decimal('160.5'), Decimal('165.25'), Decimal('159.45'), Decimal('163.0'), 4836865, 'HINDALCO', datetime.datetime(2014, 9, 18, 0, 0)),
#  (162, Decimal('163.3'), Decimal('166.5'), Decimal('162.1'), Decimal('164.3'), 8650571, 'HINDALCO', datetime.datetime(2014, 9, 19, 0, 0)),
#  (163, Decimal('164.1'), Decimal('165.35'), Decimal('160.25'), Decimal('162.2'), 5133026, 'HINDALCO', datetime.datetime(2014, 9, 22, 0, 0)),
#  (164, Decimal('161.55'), Decimal('164.0'), Decimal('155.2'), Decimal('157.15'), 7484298, 'HINDALCO', datetime.datetime(2014, 9, 23, 0, 0)),
#  (165, Decimal('155.6'), Decimal('162.5'), Decimal('148.7'), Decimal('156.1'), 22873474, 'HINDALCO', datetime.datetime(2014, 9, 24, 0, 0)),
#  (166, Decimal('154.8'), Decimal('155.65'), Decimal('133.05'), Decimal('149.15'), 31086655, 'HINDALCO', datetime.datetime(2014, 9, 25, 0, 0)),
#  (167, Decimal('146.7'), Decimal('159.1'), Decimal('146.1'), Decimal('157.25'), 13351556, 'HINDALCO', datetime.datetime(2014, 9, 26, 0, 0)),
#  (168, Decimal('157.8'), Decimal('161.65'), Decimal('153.6'), Decimal('159.7'), 9198699, 'HINDALCO', datetime.datetime(2014, 9, 29, 0, 0)),
#  (169, Decimal('158.5'), Decimal('163.0'), Decimal('155.9'), Decimal('156.75'), 10734306, 'HINDALCO', datetime.datetime(2014, 9, 30, 0, 0)),
#  (170, Decimal('155.2'), Decimal('158.4'), Decimal('152.65'), Decimal('155.25'), 8703260, 'HINDALCO', datetime.datetime(2014, 10, 1, 0, 0)),
#  (171, Decimal('153.8'), Decimal('154.55'), Decimal('147.25'), Decimal('148.25'), 12921339, 'HINDALCO', datetime.datetime(2014, 10, 7, 0, 0)),
#  (172, Decimal('146.8'), Decimal('149.8'), Decimal('145.7'), Decimal('148.8'), 9467940, 'HINDALCO', datetime.datetime(2014, 10, 8, 0, 0)),
#  (173, Decimal('151.1'), Decimal('158.5'), Decimal('151.1'), Decimal('157.85'), 12406852, 'HINDALCO', datetime.datetime(2014, 10, 9, 0, 0)),
#  (174, Decimal('155.05'), Decimal('155.05'), Decimal('149.45'), Decimal('150.15'), 10095610, 'HINDALCO', datetime.datetime(2014, 10, 10, 0, 0)),
#  (175, Decimal('149.7'), Decimal('152.0'), Decimal('147.4'), Decimal('151.1'), 7777533, 'HINDALCO', datetime.datetime(2014, 10, 13, 0, 0)),
#  (176, Decimal('151.6'), Decimal('155.2'), Decimal('147.55'), Decimal('151.0'), 11878963, 'HINDALCO', datetime.datetime(2014, 10, 14, 0, 0)),
#  (177, Decimal('151.0'), Decimal('151.0'), Decimal('141.3'), Decimal('142.4'), 11734190, 'HINDALCO', datetime.datetime(2014, 10, 16, 0, 0)),
#  (178, Decimal('143.0'), Decimal('144.0'), Decimal('138.15'), Decimal('139.45'), 13305567, 'HINDALCO', datetime.datetime(2014, 10, 17, 0, 0)),
#  (179, Decimal('143.0'), Decimal('147.55'), Decimal('141.95'), Decimal('146.5'), 10451491, 'HINDALCO', datetime.datetime(2014, 10, 20, 0, 0)),
#  (180, Decimal('147.55'), Decimal('150.9'), Decimal('147.05'), Decimal('147.9'), 8449946, 'HINDALCO', datetime.datetime(2014, 10, 21, 0, 0)),
#  (181, Decimal('150.0'), Decimal('151.0'), Decimal('145.5'), Decimal('148.45'), 7869325, 'HINDALCO', datetime.datetime(2014, 10, 22, 0, 0)),
#  (182, Decimal('149.9'), Decimal('149.95'), Decimal('149.0'), Decimal('149.25'), 657080, 'HINDALCO', datetime.datetime(2014, 10, 23, 0, 0)),
#  (183, Decimal('150.0'), Decimal('151.5'), Decimal('146.55'), Decimal('147.35'), 6682773, 'HINDALCO', datetime.datetime(2014, 10, 27, 0, 0)),
#  (184, Decimal('146.6'), Decimal('148.9'), Decimal('144.65'), Decimal('147.7'), 6866486, 'HINDALCO', datetime.datetime(2014, 10, 28, 0, 0)),
#  (185, Decimal('148.2'), Decimal('158.3'), Decimal('148.2'), Decimal('156.9'), 12809507, 'HINDALCO', datetime.datetime(2014, 10, 29, 0, 0)),
#  (186, Decimal('156.75'), Decimal('162.0'), Decimal('154.6'), Decimal('160.35'), 11033080, 'HINDALCO', datetime.datetime(2014, 10, 30, 0, 0)),
#  (187, Decimal('160.2'), Decimal('164.45'), Decimal('158.8'), Decimal('163.7'), 7740469, 'HINDALCO', datetime.datetime(2014, 10, 31, 0, 0)),
#  (188, Decimal('163.1'), Decimal('166.0'), Decimal('160.5'), Decimal('163.55'), 7051365, 'HINDALCO', datetime.datetime(2014, 11, 3, 0, 0)),
#  (189, Decimal('163.45'), Decimal('164.05'), Decimal('155.3'), Decimal('156.5'), 8390745, 'HINDALCO', datetime.datetime(2014, 11, 5, 0, 0)),
#  (190, Decimal('157.05'), Decimal('160.45'), Decimal('154.6'), Decimal('156.1'), 9383309, 'HINDALCO', datetime.datetime(2014, 11, 7, 0, 0)),
#  (191, Decimal('156.55'), Decimal('157.0'), Decimal('151.5'), Decimal('152.0'), 9011011, 'HINDALCO', datetime.datetime(2014, 11, 10, 0, 0)),
#  (192, Decimal('153.0'), Decimal('154.8'), Decimal('149.65'), Decimal('151.25'), 11436433, 'HINDALCO', datetime.datetime(2014, 11, 11, 0, 0)),
#  (193, Decimal('151.5'), Decimal('153.65'), Decimal('150.65'), Decimal('151.3'), 10127123, 'HINDALCO', datetime.datetime(2014, 11, 12, 0, 0)),
#  (194, Decimal('152.3'), Decimal('154.5'), Decimal('149.6'), Decimal('151.9'), 13597431, 'HINDALCO', datetime.datetime(2014, 11, 13, 0, 0)),
#  (195, Decimal('152.0'), Decimal('158.65'), Decimal('150.95'), Decimal('157.3'), 10434031, 'HINDALCO', datetime.datetime(2014, 11, 14, 0, 0)),
#  (196, Decimal('156.15'), Decimal('159.05'), Decimal('155.5'), Decimal('158.05'), 5914642, 'HINDALCO', datetime.datetime(2014, 11, 17, 0, 0)),
#  (197, Decimal('157.0'), Decimal('160.75'), Decimal('154.55'), Decimal('155.3'), 9471205, 'HINDALCO', datetime.datetime(2014, 11, 18, 0, 0)),
#  (198, Decimal('157.5'), Decimal('160.2'), Decimal('154.05'), Decimal('154.75'), 9177295, 'HINDALCO', datetime.datetime(2014, 11, 19, 0, 0)),
#  (199, Decimal('156.5'), Decimal('157.6'), Decimal('154.1'), Decimal('156.0'), 6453261, 'HINDALCO', datetime.datetime(2014, 11, 20, 0, 0)),
#  (200, Decimal('156.5'), Decimal('161.0'), Decimal('155.9'), Decimal('160.3'), 8704409, 'HINDALCO', datetime.datetime(2014, 11, 21, 0, 0)),
#  (201, Decimal('162.65'), Decimal('168.0'), Decimal('161.95'), Decimal('165.65'), 10540335, 'HINDALCO', datetime.datetime(2014, 11, 24, 0, 0)),
#  (202, Decimal('165.6'), Decimal('166.5'), Decimal('158.8'), Decimal('165.55'), 9865469, 'HINDALCO', datetime.datetime(2014, 11, 25, 0, 0)),
#  (203, Decimal('164.6'), Decimal('169.8'), Decimal('162.15'), Decimal('169.15'), 7594843, 'HINDALCO', datetime.datetime(2014, 11, 26, 0, 0)),
#  (204, Decimal('170.0'), Decimal('176.6'), Decimal('168.8'), Decimal('172.6'), 16167478, 'HINDALCO', datetime.datetime(2014, 11, 27, 0, 0)),
#  (205, Decimal('173.4'), Decimal('175.2'), Decimal('172.1'), Decimal('174.05'), 8705076, 'HINDALCO', datetime.datetime(2014, 11, 28, 0, 0)),
#  (206, Decimal('173.0'), Decimal('175.05'), Decimal('165.65'), Decimal('167.4'), 9673977, 'HINDALCO', datetime.datetime(2014, 12, 1, 0, 0)),
#  (207, Decimal('167.0'), Decimal('172.25'), Decimal('166.0'), Decimal('171.05'), 9360449, 'HINDALCO', datetime.datetime(2014, 12, 2, 0, 0)),
#  (208, Decimal('171.8'), Decimal('173.0'), Decimal('168.0'), Decimal('169.05'), 6342942, 'HINDALCO', datetime.datetime(2014, 12, 3, 0, 0)),
#  (209, Decimal('170.05'), Decimal('171.3'), Decimal('165.3'), Decimal('165.9'), 7635372, 'HINDALCO', datetime.datetime(2014, 12, 4, 0, 0)),
#  (210, Decimal('167.45'), Decimal('167.8'), Decimal('162.9'), Decimal('163.2'), 6802949, 'HINDALCO', datetime.datetime(2014, 12, 5, 0, 0)),
#  (211, Decimal('162.75'), Decimal('164.85'), Decimal('157.8'), Decimal('159.15'), 9025091, 'HINDALCO', datetime.datetime(2014, 12, 8, 0, 0)),
#  (212, Decimal('157.7'), Decimal('158.75'), Decimal('152.5'), Decimal('154.45'), 7678563, 'HINDALCO', datetime.datetime(2014, 12, 9, 0, 0)),
#  (213, Decimal('154.8'), Decimal('157.2'), Decimal('153.2'), Decimal('154.0'), 4808967, 'HINDALCO', datetime.datetime(2014, 12, 10, 0, 0)),
#  (214, Decimal('153.3'), Decimal('157.05'), Decimal('151.5'), Decimal('155.55'), 5043248, 'HINDALCO', datetime.datetime(2014, 12, 11, 0, 0)),
#  (215, Decimal('158.0'), Decimal('158.0'), Decimal('152.1'), Decimal('153.55'), 6382001, 'HINDALCO', datetime.datetime(2014, 12, 12, 0, 0)),
#  (216, Decimal('152.0'), Decimal('155.2'), Decimal('151.5'), Decimal('153.2'), 5268900, 'HINDALCO', datetime.datetime(2014, 12, 15, 0, 0)),
#  (217, Decimal('151.0'), Decimal('151.85'), Decimal('141.85'), Decimal('144.75'), 16684445, 'HINDALCO', datetime.datetime(2014, 12, 16, 0, 0)),
#  (218, Decimal('143.0'), Decimal('148.2'), Decimal('139.0'), Decimal('147.1'), 11916627, 'HINDALCO', datetime.datetime(2014, 12, 17, 0, 0)),
#  (219, Decimal('149.0'), Decimal('154.95'), Decimal('149.0'), Decimal('152.95'), 8113040, 'HINDALCO', datetime.datetime(2014, 12, 18, 0, 0)),
#  (220, Decimal('152.0'), Decimal('158.5'), Decimal('152.0'), Decimal('157.8'), 11532006, 'HINDALCO', datetime.datetime(2014, 12, 19, 0, 0)),
#  (221, Decimal('156.5'), Decimal('158.85'), Decimal('154.95'), Decimal('155.8'), 4714890, 'HINDALCO', datetime.datetime(2014, 12, 22, 0, 0)),
#  (222, Decimal('155.1'), Decimal('155.7'), Decimal('152.2'), Decimal('153.1'), 6821884, 'HINDALCO', datetime.datetime(2014, 12, 23, 0, 0)),
#  (223, Decimal('153.1'), Decimal('153.5'), Decimal('149.6'), Decimal('150.6'), 8568559, 'HINDALCO', datetime.datetime(2014, 12, 24, 0, 0)),
#  (224, Decimal('150.75'), Decimal('153.6'), Decimal('149.75'), Decimal('152.0'), 4821806, 'HINDALCO', datetime.datetime(2014, 12, 26, 0, 0)),
#  (225, Decimal('153.0'), Decimal('157.9'), Decimal('152.2'), Decimal('157.05'), 4804910, 'HINDALCO', datetime.datetime(2014, 12, 29, 0, 0)),
#  (226, Decimal('157.1'), Decimal('157.6'), Decimal('154.75'), Decimal('156.35'), 3056250, 'HINDALCO', datetime.datetime(2014, 12, 30, 0, 0)),
#  (227, Decimal('156.45'), Decimal('159.7'), Decimal('156.4'), Decimal('157.55'), 4327309, 'HINDALCO', datetime.datetime(2014, 12, 31, 0, 0)),
#  (228, Decimal('157.4'), Decimal('159.0'), Decimal('155.4'), Decimal('158.45'), 2350082, 'HINDALCO', datetime.datetime(2015, 1, 1, 0, 0)),
#  (229, Decimal('158.9'), Decimal('161.2'), Decimal('158.35'), Decimal('160.1'), 2923839, 'HINDALCO', datetime.datetime(2015, 1, 2, 0, 0)),
#  (230, Decimal('161.0'), Decimal('161.95'), Decimal('155.5'), Decimal('156.85'), 4830121, 'HINDALCO', datetime.datetime(2015, 1, 5, 0, 0)),
#  (231, Decimal('156.3'), Decimal('156.3'), Decimal('151.15'), Decimal('153.4'), 7054029, 'HINDALCO', datetime.datetime(2015, 1, 6, 0, 0)),
#  (232, Decimal('153.8'), Decimal('154.5'), Decimal('146.7'), Decimal('148.9'), 6638158, 'HINDALCO', datetime.datetime(2015, 1, 7, 0, 0)),
#  (233, Decimal('150.7'), Decimal('153.2'), Decimal('148.55'), Decimal('152.55'), 3540099, 'HINDALCO', datetime.datetime(2015, 1, 8, 0, 0)),
#  (234, Decimal('153.1'), Decimal('155.25'), Decimal('152.1'), Decimal('155.0'), 3743205, 'HINDALCO', datetime.datetime(2015, 1, 9, 0, 0)),
#  (235, Decimal('155.2'), Decimal('155.2'), Decimal('150.5'), Decimal('151.1'), 4659450, 'HINDALCO', datetime.datetime(2015, 1, 12, 0, 0)),
#  (236, Decimal('152.1'), Decimal('154.4'), Decimal('150.75'), Decimal('151.7'), 4324660, 'HINDALCO', datetime.datetime(2015, 1, 13, 0, 0)),
#  (237, Decimal('150.95'), Decimal('151.35'), Decimal('140.8'), Decimal('142.15'), 13580758, 'HINDALCO', datetime.datetime(2015, 1, 14, 0, 0)),
#  (238, Decimal('143.55'), Decimal('145.75'), Decimal('138.35'), Decimal('141.9'), 10860317, 'HINDALCO', datetime.datetime(2015, 1, 15, 0, 0)),
#  (239, Decimal('141.5'), Decimal('143.4'), Decimal('137.75'), Decimal('138.55'), 9096928, 'HINDALCO', datetime.datetime(2015, 1, 16, 0, 0)),
#  (240, Decimal('140.95'), Decimal('141.7'), Decimal('139.5'), Decimal('140.25'), 8541810, 'HINDALCO', datetime.datetime(2015, 1, 19, 0, 0)),
#  (241, Decimal('141.0'), Decimal('145.2'), Decimal('141.0'), Decimal('144.7'), 8856169, 'HINDALCO', datetime.datetime(2015, 1, 20, 0, 0)),
#  (242, Decimal('145.65'), Decimal('146.35'), Decimal('140.5'), Decimal('143.2'), 8871757, 'HINDALCO', datetime.datetime(2015, 1, 21, 0, 0)),
#  (243, Decimal('143.05'), Decimal('144.9'), Decimal('141.1'), Decimal('143.45'), 6918171, 'HINDALCO', datetime.datetime(2015, 1, 22, 0, 0)),
#  (244, Decimal('145.6'), Decimal('146.25'), Decimal('142.1'), Decimal('144.8'), 6943971, 'HINDALCO', datetime.datetime(2015, 1, 23, 0, 0)),
#  (245, Decimal('139.9'), Decimal('144.5'), Decimal('139.0'), Decimal('142.5'), 7886739, 'HINDALCO', datetime.datetime(2015, 1, 27, 0, 0)),
#  (246, Decimal('141.75'), Decimal('143.1'), Decimal('139.65'), Decimal('140.15'), 7496686, 'HINDALCO', datetime.datetime(2015, 1, 28, 0, 0)),
#  (247, Decimal('139.9'), Decimal('142.9'), Decimal('138.25'), Decimal('142.4'), 10636771, 'HINDALCO', datetime.datetime(2015, 1, 29, 0, 0)),
#  (248, Decimal('143.0'), Decimal('143.1'), Decimal('138.6'), Decimal('139.7'), 7570814, 'HINDALCO', datetime.datetime(2015, 1, 30, 0, 0)),
#  (249, Decimal('140.0'), Decimal('145.7'), Decimal('139.5'), Decimal('145.25'), 7296741, 'HINDALCO', datetime.datetime(2015, 2, 2, 0, 0)),
#  (250, Decimal('145.85'), Decimal('148.5'), Decimal('142.9'), Decimal('146.45'), 6262548, 'HINDALCO', datetime.datetime(2015, 2, 3, 0, 0)),
#  (251, Decimal('147.0'), Decimal('153.8'), Decimal('146.0'), Decimal('152.4'), 8349284, 'HINDALCO', datetime.datetime(2015, 2, 4, 0, 0)),
#  (252, Decimal('152.3'), Decimal('153.9'), Decimal('146.75'), Decimal('148.05'), 6672029, 'HINDALCO', datetime.datetime(2015, 2, 5, 0, 0)),
#  (253, Decimal('148.0'), Decimal('150.0'), Decimal('145.65'), Decimal('147.3'), 5623571, 'HINDALCO', datetime.datetime(2015, 2, 6, 0, 0)),
#  (254, Decimal('146.3'), Decimal('149.0'), Decimal('145.5'), Decimal('146.55'), 9737189, 'HINDALCO', datetime.datetime(2015, 2, 9, 0, 0)),
#  (255, Decimal('148.5'), Decimal('153.7'), Decimal('146.55'), Decimal('149.2'), 8706407, 'HINDALCO', datetime.datetime(2015, 2, 10, 0, 0)),
#  (256, Decimal('149.55'), Decimal('151.5'), Decimal('147.05'), Decimal('149.85'), 6154345, 'HINDALCO', datetime.datetime(2015, 2, 11, 0, 0)),
#  (257, Decimal('151.8'), Decimal('153.4'), Decimal('149.05'), Decimal('152.8'), 10713094, 'HINDALCO', datetime.datetime(2015, 2, 12, 0, 0)),
#  (258, Decimal('153.0'), Decimal('156.1'), Decimal('152.0'), Decimal('153.55'), 5666609, 'HINDALCO', datetime.datetime(2015, 2, 13, 0, 0)),
#  (259, Decimal('157.0'), Decimal('158.0'), Decimal('150.25'), Decimal('150.95'), 4949268, 'HINDALCO', datetime.datetime(2015, 2, 16, 0, 0)),
#  (260, Decimal('151.0'), Decimal('152.45'), Decimal('149.6'), Decimal('151.65'), 3717870, 'HINDALCO', datetime.datetime(2015, 2, 18, 0, 0)),
#  (261, Decimal('151.0'), Decimal('157.8'), Decimal('150.1'), Decimal('156.25'), 8185032, 'HINDALCO', datetime.datetime(2015, 2, 19, 0, 0)),
#  (262, Decimal('158.0'), Decimal('160.7'), Decimal('155.2'), Decimal('156.55'), 6630757, 'HINDALCO', datetime.datetime(2015, 2, 20, 0, 0)),
#  (263, Decimal('161.6'), Decimal('161.8'), Decimal('154.2'), Decimal('154.85'), 6743403, 'HINDALCO', datetime.datetime(2015, 2, 23, 0, 0)),
#  (264, Decimal('155.0'), Decimal('156.9'), Decimal('151.4'), Decimal('153.65'), 6455384, 'HINDALCO', datetime.datetime(2015, 2, 24, 0, 0)),
#  (265, Decimal('154.6'), Decimal('155.45'), Decimal('152.25'), Decimal('153.65'), 3479311, 'HINDALCO', datetime.datetime(2015, 2, 25, 0, 0)),
#  (266, Decimal('153.1'), Decimal('154.0'), Decimal('148.0'), Decimal('149.75'), 9010829, 'HINDALCO', datetime.datetime(2015, 2, 26, 0, 0)),
#  (267, Decimal('150.55'), Decimal('155.8'), Decimal('149.8'), Decimal('155.15'), 6534491, 'HINDALCO', datetime.datetime(2015, 2, 27, 0, 0)),
#  (268, Decimal('156.3'), Decimal('156.7'), Decimal('151.0'), Decimal('152.85'), 3999382, 'HINDALCO', datetime.datetime(2015, 2, 28, 0, 0)),
#  (269, Decimal('154.2'), Decimal('157.4'), Decimal('153.5'), Decimal('156.55'), 4452819, 'HINDALCO', datetime.datetime(2015, 3, 2, 0, 0)),
#  (270, Decimal('157.5'), Decimal('159.3'), Decimal('156.15'), Decimal('158.7'), 3718817, 'HINDALCO', datetime.datetime(2015, 3, 3, 0, 0)),
#  (271, Decimal('160.0'), Decimal('160.0'), Decimal('152.3'), Decimal('153.1'), 5559004, 'HINDALCO', datetime.datetime(2015, 3, 4, 0, 0)),
#  (272, Decimal('153.05'), Decimal('154.0'), Decimal('146.9'), Decimal('148.1'), 8404364, 'HINDALCO', datetime.datetime(2015, 3, 5, 0, 0)),
#  (273, Decimal('149.4'), Decimal('149.85'), Decimal('140.0'), Decimal('140.8'), 8031261, 'HINDALCO', datetime.datetime(2015, 3, 9, 0, 0)),
#  (274, Decimal('142.6'), Decimal('142.6'), Decimal('136.65'), Decimal('138.05'), 6588296, 'HINDALCO', datetime.datetime(2015, 3, 10, 0, 0)),
#  (275, Decimal('138.85'), Decimal('138.85'), Decimal('127.2'), Decimal('130.35'), 21561044, 'HINDALCO', datetime.datetime(2015, 3, 11, 0, 0)),
#  (276, Decimal('131.75'), Decimal('135.7'), Decimal('129.1'), Decimal('134.9'), 14242872, 'HINDALCO', datetime.datetime(2015, 3, 12, 0, 0)),
#  (277, Decimal('136.7'), Decimal('136.75'), Decimal('131.05'), Decimal('131.7'), 6690050, 'HINDALCO', datetime.datetime(2015, 3, 13, 0, 0)),
#  (278, Decimal('131.0'), Decimal('131.4'), Decimal('123.1'), Decimal('126.8'), 10785285, 'HINDALCO', datetime.datetime(2015, 3, 16, 0, 0)),
#  (279, Decimal('128.0'), Decimal('134.75'), Decimal('126.8'), Decimal('134.25'), 9699896, 'HINDALCO', datetime.datetime(2015, 3, 17, 0, 0)),
#  (280, Decimal('134.0'), Decimal('134.8'), Decimal('131.8'), Decimal('133.15'), 4154051, 'HINDALCO', datetime.datetime(2015, 3, 18, 0, 0)),
#  (281, Decimal('134.0'), Decimal('136.2'), Decimal('131.3'), Decimal('132.3'), 4626972, 'HINDALCO', datetime.datetime(2015, 3, 19, 0, 0)),
#  (282, Decimal('132.15'), Decimal('135.0'), Decimal('130.55'), Decimal('132.05'), 4836454, 'HINDALCO', datetime.datetime(2015, 3, 20, 0, 0)),
#  (283, Decimal('131.95'), Decimal('136.8'), Decimal('131.95'), Decimal('135.9'), 6306085, 'HINDALCO', datetime.datetime(2015, 3, 23, 0, 0)),
#  (284, Decimal('135.8'), Decimal('135.9'), Decimal('132.0'), Decimal('132.85'), 4386125, 'HINDALCO', datetime.datetime(2015, 3, 24, 0, 0)),
#  (285, Decimal('133.0'), Decimal('134.45'), Decimal('132.35'), Decimal('132.9'), 2895061, 'HINDALCO', datetime.datetime(2015, 3, 25, 0, 0)),
#  (286, Decimal('132.4'), Decimal('133.4'), Decimal('128.55'), Decimal('129.55'), 7955596, 'HINDALCO', datetime.datetime(2015, 3, 26, 0, 0)),
#  (287, Decimal('131.0'), Decimal('134.45'), Decimal('130.05'), Decimal('133.95'), 5241353, 'HINDALCO', datetime.datetime(2015, 3, 27, 0, 0)),
#  (288, Decimal('134.25'), Decimal('134.7'), Decimal('130.3'), Decimal('131.15'), 3651285, 'HINDALCO', datetime.datetime(2015, 3, 30, 0, 0)),
#  (289, Decimal('133.0'), Decimal('133.45'), Decimal('128.4'), Decimal('129.0'), 8516432, 'HINDALCO', datetime.datetime(2015, 3, 31, 0, 0)),
#  (290, Decimal('129.0'), Decimal('132.9'), Decimal('127.5'), Decimal('132.2'), 7180617, 'HINDALCO', datetime.datetime(2015, 4, 1, 0, 0)),
#  (291, Decimal('133.4'), Decimal('135.1'), Decimal('132.0'), Decimal('134.7'), 5542921, 'HINDALCO', datetime.datetime(2015, 4, 6, 0, 0)),
#  (292, Decimal('135.0'), Decimal('137.55'), Decimal('134.2'), Decimal('136.95'), 6514199, 'HINDALCO', datetime.datetime(2015, 4, 7, 0, 0)),
#  (293, Decimal('137.25'), Decimal('138.9'), Decimal('136.15'), Decimal('137.95'), 6176434, 'HINDALCO', datetime.datetime(2015, 4, 8, 0, 0)),
#  (294, Decimal('138.6'), Decimal('140.85'), Decimal('136.6'), Decimal('139.9'), 6142066, 'HINDALCO', datetime.datetime(2015, 4, 9, 0, 0)),
#  (295, Decimal('139.0'), Decimal('139.2'), Decimal('137.05'), Decimal('137.9'), 4860480, 'HINDALCO', datetime.datetime(2015, 4, 10, 0, 0)),
#  (296, Decimal('138.0'), Decimal('138.95'), Decimal('135.1'), Decimal('136.1'), 5017864, 'HINDALCO', datetime.datetime(2015, 4, 13, 0, 0)),
#  (297, Decimal('136.0'), Decimal('137.4'), Decimal('134.6'), Decimal('135.15'), 8714291, 'HINDALCO', datetime.datetime(2015, 4, 15, 0, 0)),
#  (298, Decimal('135.85'), Decimal('137.9'), Decimal('135.4'), Decimal('137.15'), 5457847, 'HINDALCO', datetime.datetime(2015, 4, 16, 0, 0)),
#  (299, Decimal('138.0'), Decimal('141.7'), Decimal('137.6'), Decimal('139.75'), 8674061, 'HINDALCO', datetime.datetime(2015, 4, 17, 0, 0)),
#  (300, Decimal('140.9'), Decimal('141.7'), Decimal('137.2'), Decimal('138.25'), 5669966, 'HINDALCO', datetime.datetime(2015, 4, 20, 0, 0)),
#  (301, Decimal('138.4'), Decimal('139.35'), Decimal('133.7'), Decimal('134.3'), 6236971, 'HINDALCO', datetime.datetime(2015, 4, 21, 0, 0)),
#  (302, Decimal('133.5'), Decimal('135.5'), Decimal('132.6'), Decimal('134.65'), 6263990, 'HINDALCO', datetime.datetime(2015, 4, 22, 0, 0)),
#  (303, Decimal('135.5'), Decimal('137.0'), Decimal('133.8'), Decimal('135.05'), 6782890, 'HINDALCO', datetime.datetime(2015, 4, 23, 0, 0)),
#  (304, Decimal('134.85'), Decimal('135.8'), Decimal('130.1'), Decimal('131.15'), 7487405, 'HINDALCO', datetime.datetime(2015, 4, 24, 0, 0)),
#  (305, Decimal('132.0'), Decimal('132.95'), Decimal('128.25'), Decimal('130.05'), 4805160, 'HINDALCO', datetime.datetime(2015, 4, 27, 0, 0)),
#  (306, Decimal('130.9'), Decimal('132.45'), Decimal('129.6'), Decimal('131.35'), 6154792, 'HINDALCO', datetime.datetime(2015, 4, 28, 0, 0)),
#  (307, Decimal('131.4'), Decimal('131.4'), Decimal('128.7'), Decimal('130.6'), 7223085, 'HINDALCO', datetime.datetime(2015, 4, 29, 0, 0)),
#  (308, Decimal('130.0'), Decimal('130.9'), Decimal('127.05'), Decimal('128.6'), 11618447, 'HINDALCO', datetime.datetime(2015, 4, 30, 0, 0)),
#  (309, Decimal('130.4'), Decimal('133.6'), Decimal('129.5'), Decimal('133.15'), 4003261, 'HINDALCO', datetime.datetime(2015, 5, 4, 0, 0)),
#  (310, Decimal('133.45'), Decimal('140.2'), Decimal('132.35'), Decimal('139.35'), 8946517, 'HINDALCO', datetime.datetime(2015, 5, 5, 0, 0)),
#  (311, Decimal('138.9'), Decimal('142.0'), Decimal('135.05'), Decimal('137.75'), 9503948, 'HINDALCO', datetime.datetime(2015, 5, 6, 0, 0)),
#  (312, Decimal('136.9'), Decimal('136.9'), Decimal('132.25'), Decimal('134.3'), 5764064, 'HINDALCO', datetime.datetime(2015, 5, 7, 0, 0)),
#  (313, Decimal('135.2'), Decimal('139.5'), Decimal('134.85'), Decimal('138.95'), 4144037, 'HINDALCO', datetime.datetime(2015, 5, 8, 0, 0)),
#  (314, Decimal('140.8'), Decimal('145.1'), Decimal('140.2'), Decimal('142.5'), 6190079, 'HINDALCO', datetime.datetime(2015, 5, 11, 0, 0)),
#  (315, Decimal('142.4'), Decimal('142.5'), Decimal('136.2'), Decimal('137.6'), 5822453, 'HINDALCO', datetime.datetime(2015, 5, 12, 0, 0)),
#  (316, Decimal('134.9'), Decimal('136.4'), Decimal('131.75'), Decimal('133.5'), 9200683, 'HINDALCO', datetime.datetime(2015, 5, 13, 0, 0)),
#  (317, Decimal('134.1'), Decimal('138.0'), Decimal('132.5'), Decimal('137.45'), 3697331, 'HINDALCO', datetime.datetime(2015, 5, 14, 0, 0)),
#  (318, Decimal('137.7'), Decimal('138.75'), Decimal('134.55'), Decimal('137.0'), 3519076, 'HINDALCO', datetime.datetime(2015, 5, 15, 0, 0)),
#  (319, Decimal('138.0'), Decimal('141.85'), Decimal('137.9'), Decimal('139.1'), 5044666, 'HINDALCO', datetime.datetime(2015, 5, 18, 0, 0)),
#  (320, Decimal('138.85'), Decimal('140.55'), Decimal('136.6'), Decimal('139.95'), 4364176, 'HINDALCO', datetime.datetime(2015, 5, 19, 0, 0)),
#  (321, Decimal('140.65'), Decimal('140.65'), Decimal('138.15'), Decimal('138.95'), 3050410, 'HINDALCO', datetime.datetime(2015, 5, 20, 0, 0)),
#  (322, Decimal('137.7'), Decimal('139.9'), Decimal('136.25'), Decimal('139.1'), 3942179, 'HINDALCO', datetime.datetime(2015, 5, 21, 0, 0)),
#  (323, Decimal('139.0'), Decimal('139.0'), Decimal('136.5'), Decimal('136.9'), 2577977, 'HINDALCO', datetime.datetime(2015, 5, 22, 0, 0)),
#  (324, Decimal('136.75'), Decimal('138.4'), Decimal('133.9'), Decimal('134.5'), 2879752, 'HINDALCO', datetime.datetime(2015, 5, 25, 0, 0)),
#  (325, Decimal('135.15'), Decimal('135.65'), Decimal('133.2'), Decimal('134.3'), 2693352, 'HINDALCO', datetime.datetime(2015, 5, 26, 0, 0)),
#  (326, Decimal('133.0'), Decimal('134.6'), Decimal('132.2'), Decimal('133.55'), 3168751, 'HINDALCO', datetime.datetime(2015, 5, 27, 0, 0)),
#  (327, Decimal('132.6'), Decimal('134.0'), Decimal('129.8'), Decimal('131.6'), 10174628, 'HINDALCO', datetime.datetime(2015, 5, 28, 0, 0)),
#  (328, Decimal('130.95'), Decimal('133.2'), Decimal('128.55'), Decimal('129.25'), 11477479, 'HINDALCO', datetime.datetime(2015, 5, 29, 0, 0)),
#  (329, Decimal('128.75'), Decimal('129.8'), Decimal('127.75'), Decimal('128.35'), 3272418, 'HINDALCO', datetime.datetime(2015, 6, 1, 0, 0)),
#  (330, Decimal('128.95'), Decimal('129.2'), Decimal('122.9'), Decimal('123.25'), 4980345, 'HINDALCO', datetime.datetime(2015, 6, 2, 0, 0)),
#  (331, Decimal('124.05'), Decimal('124.9'), Decimal('120.0'), Decimal('121.95'), 3508099, 'HINDALCO', datetime.datetime(2015, 6, 3, 0, 0)),
#  (332, Decimal('122.3'), Decimal('123.55'), Decimal('119.0'), Decimal('121.3'), 3192106, 'HINDALCO', datetime.datetime(2015, 6, 4, 0, 0)),
#  (333, Decimal('120.95'), Decimal('122.3'), Decimal('119.15'), Decimal('120.15'), 4163808, 'HINDALCO', datetime.datetime(2015, 6, 5, 0, 0)),
#  (334, Decimal('120.25'), Decimal('121.15'), Decimal('117.7'), Decimal('118.2'), 4663365, 'HINDALCO', datetime.datetime(2015, 6, 8, 0, 0)),
#  (335, Decimal('118.0'), Decimal('121.3'), Decimal('117.55'), Decimal('120.1'), 4663442, 'HINDALCO', datetime.datetime(2015, 6, 9, 0, 0)),
#  (336, Decimal('120.5'), Decimal('121.8'), Decimal('119.65'), Decimal('120.3'), 3297811, 'HINDALCO', datetime.datetime(2015, 6, 10, 0, 0)),
#  (337, Decimal('120.7'), Decimal('121.5'), Decimal('118.6'), Decimal('119.2'), 4749485, 'HINDALCO', datetime.datetime(2015, 6, 11, 0, 0)),
#  (338, Decimal('118.75'), Decimal('119.25'), Decimal('116.1'), Decimal('116.75'), 5422403, 'HINDALCO', datetime.datetime(2015, 6, 12, 0, 0)),
#  (339, Decimal('116.2'), Decimal('117.15'), Decimal('113.8'), Decimal('114.3'), 4287348, 'HINDALCO', datetime.datetime(2015, 6, 15, 0, 0)),
#  (340, Decimal('114.65'), Decimal('115.5'), Decimal('113.6'), Decimal('115.0'), 5266441, 'HINDALCO', datetime.datetime(2015, 6, 16, 0, 0)),
#  (341, Decimal('115.0'), Decimal('119.15'), Decimal('114.8'), Decimal('118.55'), 5112962, 'HINDALCO', datetime.datetime(2015, 6, 17, 0, 0)),
# ...
#  (888, Decimal('239.25'), Decimal('245.0'), Decimal('238.05'), Decimal('243.75'), 9852014, 'HINDALCO', datetime.datetime(2017, 9, 1, 0, 0)),
#  (889, Decimal('244.45'), Decimal('247.0'), Decimal('237.55'), Decimal('242.45'), 11283027, 'HINDALCO', datetime.datetime(2017, 9, 4, 0, 0)),
#  (890, Decimal('243.2'), Decimal('244.35'), Decimal('240.2'), Decimal('241.9'), 3776840, 'HINDALCO', datetime.datetime(2017, 9, 5, 0, 0)),
#  (891, Decimal('236.0'), Decimal('246.7'), Decimal('236.0'), Decimal('245.8'), 9688366, 'HINDALCO', datetime.datetime(2017, 9, 6, 0, 0)),
#  (892, Decimal('247.5'), Decimal('251.25'), Decimal('245.65'), Decimal('249.95'), 11330389, 'HINDALCO', datetime.datetime(2017, 9, 7, 0, 0)),
#  (893, Decimal('251.75'), Decimal('255.45'), Decimal('246.65'), Decimal('249.55'), 11886595, 'HINDALCO', datetime.datetime(2017, 9, 8, 0, 0)),
#  (894, Decimal('251.45'), Decimal('252.5'), Decimal('246.6'), Decimal('250.05'), 6580356, 'HINDALCO', datetime.datetime(2017, 9, 11, 0, 0)),
#  (895, Decimal('250.5'), Decimal('254.6'), Decimal('249.5'), Decimal('250.95'), 6812508, 'HINDALCO', datetime.datetime(2017, 9, 12, 0, 0)),
#  (896, Decimal('250.25'), Decimal('251.7'), Decimal('246.35'), Decimal('248.0'), 4323093, 'HINDALCO', datetime.datetime(2017, 9, 13, 0, 0)),
#  (897, Decimal('249.3'), Decimal('252.0'), Decimal('244.45'), Decimal('247.2'), 7307378, 'HINDALCO', datetime.datetime(2017, 9, 14, 0, 0)),
#  (898, Decimal('245.05'), Decimal('249.7'), Decimal('241.4'), Decimal('247.8'), 8809971, 'HINDALCO', datetime.datetime(2017, 9, 15, 0, 0)),
#  (899, Decimal('248.6'), Decimal('251.35'), Decimal('247.75'), Decimal('249.5'), 5570498, 'HINDALCO', datetime.datetime(2017, 9, 18, 0, 0)),
#  (900, Decimal('250.4'), Decimal('250.4'), Decimal('245.6'), Decimal('246.5'), 4938461, 'HINDALCO', datetime.datetime(2017, 9, 19, 0, 0)),
#  (901, Decimal('247.4'), Decimal('248.95'), Decimal('241.8'), Decimal('244.1'), 9917420, 'HINDALCO', datetime.datetime(2017, 9, 20, 0, 0)),
#  (902, Decimal('245.5'), Decimal('245.8'), Decimal('236.3'), Decimal('244.55'), 9888709, 'HINDALCO', datetime.datetime(2017, 9, 21, 0, 0)),
#  (903, Decimal('243.3'), Decimal('243.3'), Decimal('229.1'), Decimal('230.9'), 14454217, 'HINDALCO', datetime.datetime(2017, 9, 22, 0, 0)),
#  (904, Decimal('231.4'), Decimal('232.5'), Decimal('223.3'), Decimal('229.1'), 9248669, 'HINDALCO', datetime.datetime(2017, 9, 25, 0, 0)),
#  (905, Decimal('228.25'), Decimal('235.35'), Decimal('227.8'), Decimal('234.6'), 7602977, 'HINDALCO', datetime.datetime(2017, 9, 26, 0, 0)),
#  (906, Decimal('234.75'), Decimal('235.2'), Decimal('230.7'), Decimal('233.65'), 6569514, 'HINDALCO', datetime.datetime(2017, 9, 27, 0, 0)),
#  (907, Decimal('232.5'), Decimal('239.7'), Decimal('232.35'), Decimal('238.45'), 15196210, 'HINDALCO', datetime.datetime(2017, 9, 28, 0, 0)),
#  (908, Decimal('241.3'), Decimal('242.65'), Decimal('238.6'), Decimal('240.6'), 9189997, 'HINDALCO', datetime.datetime(2017, 9, 29, 0, 0)),
#  (909, Decimal('242.5'), Decimal('244.7'), Decimal('238.2'), Decimal('241.6'), 4986233, 'HINDALCO', datetime.datetime(2017, 10, 3, 0, 0)),
#  (910, Decimal('242.05'), Decimal('243.0'), Decimal('240.3'), Decimal('241.9'), 3207388, 'HINDALCO', datetime.datetime(2017, 10, 4, 0, 0)),
#  (911, Decimal('242.0'), Decimal('242.85'), Decimal('239.4'), Decimal('240.75'), 3698369, 'HINDALCO', datetime.datetime(2017, 10, 5, 0, 0)),
#  (912, Decimal('241.0'), Decimal('252.15'), Decimal('241.0'), Decimal('250.9'), 9453802, 'HINDALCO', datetime.datetime(2017, 10, 6, 0, 0)),
#  (913, Decimal('250.45'), Decimal('253.4'), Decimal('248.35'), Decimal('249.5'), 5744914, 'HINDALCO', datetime.datetime(2017, 10, 9, 0, 0)),
#  (914, Decimal('250.5'), Decimal('253.5'), Decimal('248.1'), Decimal('252.05'), 8106676, 'HINDALCO', datetime.datetime(2017, 10, 10, 0, 0)),
#  (915, Decimal('252.95'), Decimal('254.6'), Decimal('246.6'), Decimal('249.5'), 9799296, 'HINDALCO', datetime.datetime(2017, 10, 11, 0, 0)),
#  (916, Decimal('250.25'), Decimal('265.4'), Decimal('249.7'), Decimal('264.45'), 30320448, 'HINDALCO', datetime.datetime(2017, 10, 12, 0, 0)),
#  (917, Decimal('264.7'), Decimal('267.65'), Decimal('261.5'), Decimal('266.6'), 12276907, 'HINDALCO', datetime.datetime(2017, 10, 13, 0, 0)),
#  (918, Decimal('268.45'), Decimal('272.9'), Decimal('267.5'), Decimal('271.4'), 14632858, 'HINDALCO', datetime.datetime(2017, 10, 16, 0, 0)),
#  (919, Decimal('271.9'), Decimal('277.9'), Decimal('269.5'), Decimal('276.5'), 9929992, 'HINDALCO', datetime.datetime(2017, 10, 17, 0, 0)),
#  (920, Decimal('277.0'), Decimal('278.45'), Decimal('273.2'), Decimal('275.3'), 9664157, 'HINDALCO', datetime.datetime(2017, 10, 18, 0, 0)),
#  (921, Decimal('275.0'), Decimal('275.25'), Decimal('273.15'), Decimal('273.9'), 569539, 'HINDALCO', datetime.datetime(2017, 10, 19, 0, 0)),
#  (922, Decimal('274.65'), Decimal('278.55'), Decimal('269.45'), Decimal('271.9'), 6263035, 'HINDALCO', datetime.datetime(2017, 10, 23, 0, 0)),
#  (923, Decimal('269.6'), Decimal('275.0'), Decimal('267.5'), Decimal('268.85'), 9597374, 'HINDALCO', datetime.datetime(2017, 10, 24, 0, 0)),
#  (924, Decimal('271.8'), Decimal('272.4'), Decimal('264.25'), Decimal('266.75'), 7240195, 'HINDALCO', datetime.datetime(2017, 10, 25, 0, 0)),
#  (925, Decimal('269.25'), Decimal('275.3'), Decimal('268.0'), Decimal('272.9'), 8484342, 'HINDALCO', datetime.datetime(2017, 10, 26, 0, 0)),
#  (926, Decimal('275.95'), Decimal('276.3'), Decimal('269.15'), Decimal('270.05'), 4587536, 'HINDALCO', datetime.datetime(2017, 10, 27, 0, 0)),
#  (927, Decimal('270.55'), Decimal('275.8'), Decimal('270.45'), Decimal('273.2'), 4647384, 'HINDALCO', datetime.datetime(2017, 10, 30, 0, 0)),
#  (928, Decimal('272.2'), Decimal('273.8'), Decimal('264.75'), Decimal('267.4'), 4764121, 'HINDALCO', datetime.datetime(2017, 10, 31, 0, 0)),
#  (929, Decimal('269.5'), Decimal('276.0'), Decimal('267.6'), Decimal('275.3'), 9043536, 'HINDALCO', datetime.datetime(2017, 11, 1, 0, 0)),
#  (930, Decimal('276.0'), Decimal('276.0'), Decimal('266.35'), Decimal('270.8'), 8317616, 'HINDALCO', datetime.datetime(2017, 11, 2, 0, 0)),
#  (931, Decimal('276.4'), Decimal('277.6'), Decimal('265.6'), Decimal('268.9'), 14396735, 'HINDALCO', datetime.datetime(2017, 11, 3, 5, 30)),
#  (932, Decimal('268.7'), Decimal('274.6'), Decimal('261.0'), Decimal('272.95'), 10582403, 'HINDALCO', datetime.datetime(2017, 11, 6, 0, 0)),
#  (933, Decimal('273.85'), Decimal('274.9'), Decimal('264.0'), Decimal('266.9'), 8882930, 'HINDALCO', datetime.datetime(2017, 11, 7, 0, 0)),
#  (934, Decimal('268.2'), Decimal('269.85'), Decimal('259.2'), Decimal('263.05'), 7922193, 'HINDALCO', datetime.datetime(2017, 11, 8, 0, 0)),
#  (935, Decimal('267.1'), Decimal('267.95'), Decimal('259.0'), Decimal('263.3'), 7419140, 'HINDALCO', datetime.datetime(2017, 11, 9, 0, 0)),
#  (936, Decimal('261.5'), Decimal('267.05'), Decimal('260.8'), Decimal('264.05'), 5272277, 'HINDALCO', datetime.datetime(2017, 11, 10, 5, 30)),
#  (937, Decimal('264.0'), Decimal('265.25'), Decimal('258.8'), Decimal('260.9'), 5439255, 'HINDALCO', datetime.datetime(2017, 11, 13, 0, 0)),
#  (938, Decimal('260.1'), Decimal('264.75'), Decimal('259.15'), Decimal('261.0'), 5575097, 'HINDALCO', datetime.datetime(2017, 11, 14, 0, 0)),
#  (939, Decimal('259.5'), Decimal('259.7'), Decimal('248.4'), Decimal('251.85'), 9886735, 'HINDALCO', datetime.datetime(2017, 11, 15, 0, 0)),
#  (940, Decimal('253.55'), Decimal('256.15'), Decimal('251.35'), Decimal('254.7'), 5264913, 'HINDALCO', datetime.datetime(2017, 11, 16, 0, 0)),
#  (941, Decimal('256.75'), Decimal('263.2'), Decimal('256.75'), Decimal('258.85'), 5927180, 'HINDALCO', datetime.datetime(2017, 11, 17, 0, 0)),
#  (942, Decimal('259.0'), Decimal('262.5'), Decimal('253.3'), Decimal('261.45'), 6377940, 'HINDALCO', datetime.datetime(2017, 11, 20, 0, 0)),
#  (943, Decimal('262.6'), Decimal('265.1'), Decimal('259.25'), Decimal('261.45'), 3610061, 'HINDALCO', datetime.datetime(2017, 11, 21, 0, 0)),
#  (944, Decimal('262.8'), Decimal('263.85'), Decimal('256.8'), Decimal('257.75'), 4497727, 'HINDALCO', datetime.datetime(2017, 11, 22, 0, 0)),
#  (945, Decimal('257.0'), Decimal('258.65'), Decimal('250.05'), Decimal('255.25'), 9682203, 'HINDALCO', datetime.datetime(2017, 11, 23, 0, 0)),
#  (946, Decimal('255.3'), Decimal('255.75'), Decimal('251.0'), Decimal('251.65'), 6186665, 'HINDALCO', datetime.datetime(2017, 11, 24, 5, 30)),
#  (947, Decimal('250.9'), Decimal('253.6'), Decimal('247.2'), Decimal('249.65'), 7592581, 'HINDALCO', datetime.datetime(2017, 11, 27, 0, 0)),
#  (948, Decimal('249.15'), Decimal('253.0'), Decimal('248.0'), Decimal('250.65'), 4692698, 'HINDALCO', datetime.datetime(2017, 11, 28, 0, 0)),
#  (949, Decimal('250.9'), Decimal('251.95'), Decimal('246.0'), Decimal('246.9'), 5285364, 'HINDALCO', datetime.datetime(2017, 11, 29, 0, 0)),
#  (950, Decimal('245.1'), Decimal('247.45'), Decimal('239.5'), Decimal('240.45'), 14998374, 'HINDALCO', datetime.datetime(2017, 11, 30, 0, 0)),
#  (951, Decimal('240.5'), Decimal('241.35'), Decimal('233.55'), Decimal('235.35'), 7209250, 'HINDALCO', datetime.datetime(2017, 12, 1, 5, 30)),
#  (952, Decimal('236.5'), Decimal('240.85'), Decimal('234.65'), Decimal('239.55'), 6457124, 'HINDALCO', datetime.datetime(2017, 12, 4, 0, 0)),
#  (953, Decimal('238.85'), Decimal('241.7'), Decimal('235.7'), Decimal('240.05'), 6775195, 'HINDALCO', datetime.datetime(2017, 12, 5, 0, 0)),
#  (954, Decimal('236.5'), Decimal('236.65'), Decimal('231.2'), Decimal('232.1'), 7402990, 'HINDALCO', datetime.datetime(2017, 12, 6, 0, 0)),
#  (955, Decimal('232.5'), Decimal('238.0'), Decimal('229.4'), Decimal('237.2'), 7697931, 'HINDALCO', datetime.datetime(2017, 12, 7, 0, 0)),
#  (956, Decimal('238.45'), Decimal('243.95'), Decimal('237.55'), Decimal('239.7'), 8857585, 'HINDALCO', datetime.datetime(2017, 12, 8, 5, 30)),
#  (957, Decimal('240.0'), Decimal('240.85'), Decimal('236.05'), Decimal('238.1'), 6613622, 'HINDALCO', datetime.datetime(2017, 12, 11, 0, 0)),
#  (958, Decimal('238.45'), Decimal('243.2'), Decimal('236.6'), Decimal('237.95'), 5268296, 'HINDALCO', datetime.datetime(2017, 12, 12, 0, 0)),
#  (959, Decimal('235.65'), Decimal('239.9'), Decimal('233.55'), Decimal('234.45'), 7349390, 'HINDALCO', datetime.datetime(2017, 12, 13, 0, 0)),
#  (960, Decimal('235.5'), Decimal('238.0'), Decimal('233.05'), Decimal('236.4'), 6618531, 'HINDALCO', datetime.datetime(2017, 12, 14, 0, 0)),
#  (961, Decimal('240.85'), Decimal('243.95'), Decimal('239.1'), Decimal('242.75'), 6290840, 'HINDALCO', datetime.datetime(2017, 12, 15, 5, 30)),
#  (962, Decimal('241.0'), Decimal('254.3'), Decimal('235.5'), Decimal('249.65'), 13833894, 'HINDALCO', datetime.datetime(2017, 12, 18, 0, 0)),
#  (963, Decimal('252.0'), Decimal('254.9'), Decimal('250.6'), Decimal('254.3'), 5550113, 'HINDALCO', datetime.datetime(2017, 12, 19, 0, 0)),
#  (964, Decimal('254.5'), Decimal('261.0'), Decimal('251.2'), Decimal('258.35'), 15519081, 'HINDALCO', datetime.datetime(2017, 12, 20, 0, 0)),
#  (965, Decimal('260.9'), Decimal('264.65'), Decimal('259.65'), Decimal('263.3'), 13770746, 'HINDALCO', datetime.datetime(2017, 12, 21, 0, 0)),
#  (966, Decimal('263.5'), Decimal('269.5'), Decimal('263.35'), Decimal('267.85'), 7760233, 'HINDALCO', datetime.datetime(2017, 12, 22, 5, 30)),
#  (967, Decimal('268.8'), Decimal('270.5'), Decimal('266.5'), Decimal('268.65'), 4332214, 'HINDALCO', datetime.datetime(2017, 12, 26, 0, 0)),
#  (968, Decimal('268.9'), Decimal('269.7'), Decimal('264.7'), Decimal('265.75'), 6351948, 'HINDALCO', datetime.datetime(2017, 12, 27, 0, 0)),
#  (969, Decimal('267.0'), Decimal('278.8'), Decimal('267.0'), Decimal('275.25'), 22938436, 'HINDALCO', datetime.datetime(2017, 12, 28, 0, 0)),
#  (970, Decimal('276.75'), Decimal('276.75'), Decimal('270.7'), Decimal('273.55'), 5007765, 'HINDALCO', datetime.datetime(2017, 12, 29, 5, 30)),
#  (971, Decimal('273.0'), Decimal('277.9'), Decimal('270.0'), Decimal('271.15'), 4614411, 'HINDALCO', datetime.datetime(2018, 1, 1, 0, 0)),
#  (972, Decimal('274.4'), Decimal('274.4'), Decimal('268.1'), Decimal('271.9'), 4546324, 'HINDALCO', datetime.datetime(2018, 1, 2, 0, 0)),
#  (973, Decimal('273.4'), Decimal('279.35'), Decimal('273.1'), Decimal('276.5'), 7285874, 'HINDALCO', datetime.datetime(2018, 1, 3, 0, 0)),
#  (974, Decimal('277.1'), Decimal('281.3'), Decimal('274.8'), Decimal('279.8'), 10346774, 'HINDALCO', datetime.datetime(2018, 1, 4, 0, 0)),
#  (975, Decimal('282.0'), Decimal('284.0'), Decimal('275.1'), Decimal('276.4'), 7084973, 'HINDALCO', datetime.datetime(2018, 1, 5, 5, 30)),
#  (976, Decimal('277.0'), Decimal('279.05'), Decimal('273.7'), Decimal('276.15'), 4157464, 'HINDALCO', datetime.datetime(2018, 1, 8, 5, 30)),
#  (977, Decimal('277.55'), Decimal('277.55'), Decimal('270.65'), Decimal('271.5'), 5197857, 'HINDALCO', datetime.datetime(2018, 1, 9, 0, 0)),
#  (978, Decimal('272.8'), Decimal('276.5'), Decimal('266.6'), Decimal('268.8'), 7472579, 'HINDALCO', datetime.datetime(2018, 1, 10, 0, 0)),
#  (979, Decimal('268.8'), Decimal('271.15'), Decimal('266.8'), Decimal('267.75'), 6502699, 'HINDALCO', datetime.datetime(2018, 1, 11, 0, 0)),
#  (980, Decimal('269.0'), Decimal('271.6'), Decimal('266.65'), Decimal('268.85'), 4435500, 'HINDALCO', datetime.datetime(2018, 1, 12, 5, 30)),
#  (981, Decimal('270.2'), Decimal('274.65'), Decimal('265.8'), Decimal('266.7'), 6592272, 'HINDALCO', datetime.datetime(2018, 1, 15, 0, 0)),
#  (982, Decimal('267.8'), Decimal('268.0'), Decimal('259.7'), Decimal('260.55'), 8447591, 'HINDALCO', datetime.datetime(2018, 1, 16, 0, 0)),
#  (983, Decimal('260.3'), Decimal('265.25'), Decimal('256.45'), Decimal('262.75'), 11037340, 'HINDALCO', datetime.datetime(2018, 1, 17, 0, 0)),
#  (984, Decimal('263.7'), Decimal('263.7'), Decimal('252.1'), Decimal('253.9'), 11341249, 'HINDALCO', datetime.datetime(2018, 1, 18, 0, 0)),
#  (985, Decimal('254.0'), Decimal('259.35'), Decimal('252.2'), Decimal('258.0'), 5898314, 'HINDALCO', datetime.datetime(2018, 1, 19, 0, 0)),
#  (986, Decimal('258.0'), Decimal('258.8'), Decimal('251.1'), Decimal('255.1'), 6230212, 'HINDALCO', datetime.datetime(2018, 1, 22, 0, 0)),
#  (987, Decimal('256.1'), Decimal('270.7'), Decimal('256.1'), Decimal('264.95'), 17400430, 'HINDALCO', datetime.datetime(2018, 1, 23, 0, 0)),
#  (988, Decimal('263.55'), Decimal('264.4'), Decimal('256.8'), Decimal('258.7'), 6409442, 'HINDALCO', datetime.datetime(2018, 1, 24, 0, 0)),
#  (989, Decimal('259.3'), Decimal('266.85'), Decimal('256.4'), Decimal('258.95'), 15254979, 'HINDALCO', datetime.datetime(2018, 1, 25, 0, 0)),
#  (990, Decimal('261.6'), Decimal('263.9'), Decimal('253.4'), Decimal('258.6'), 5990929, 'HINDALCO', datetime.datetime(2018, 1, 29, 0, 0)),
#  (991, Decimal('257.75'), Decimal('258.0'), Decimal('252.55'), Decimal('253.55'), 5286436, 'HINDALCO', datetime.datetime(2018, 1, 30, 0, 0)),
#  (992, Decimal('253.4'), Decimal('263.2'), Decimal('252.0'), Decimal('256.15'), 17514495, 'HINDALCO', datetime.datetime(2018, 1, 31, 0, 0)),
#  (993, Decimal('257.8'), Decimal('259.5'), Decimal('248.75'), Decimal('256.25'), 8940788, 'HINDALCO', datetime.datetime(2018, 2, 1, 0, 0)),
#  (994, Decimal('256.45'), Decimal('261.65'), Decimal('245.75'), Decimal('249.85'), 21737420, 'HINDALCO', datetime.datetime(2018, 2, 2, 0, 0)),
#  (995, Decimal('242.5'), Decimal('249.4'), Decimal('240.25'), Decimal('246.6'), 8462501, 'HINDALCO', datetime.datetime(2018, 2, 5, 0, 0)),
#  (996, Decimal('236.0'), Decimal('248.5'), Decimal('232.5'), Decimal('244.4'), 10473645, 'HINDALCO', datetime.datetime(2018, 2, 6, 0, 0)),
#  (997, Decimal('245.0'), Decimal('253.0'), Decimal('244.1'), Decimal('246.0'), 13707458, 'HINDALCO', datetime.datetime(2018, 2, 7, 0, 0)),
#  (998, Decimal('245.6'), Decimal('249.35'), Decimal('240.5'), Decimal('245.2'), 10180978, 'HINDALCO', datetime.datetime(2018, 2, 8, 0, 0)),
#  (999, Decimal('240.0'), Decimal('245.5'), Decimal('237.35'), Decimal('243.5'), 7024965, 'HINDALCO', datetime.datetime(2018, 2, 9, 0, 0)),
#  (1000, Decimal('247.0'), Decimal('247.65'), Decimal('242.0'), Decimal('243.25'), 5557349, 'HINDALCO', datetime.datetime(2018, 2, 12, 0, 0)),
#  ...]

# %% [markdown]
# # Plotting HINDALCO Close Prices
#
# The plot using Plotly Express (px.line) visually represents the closing prices of HINDALCO stock over time (datetime). This line chart is a quick and effective way to illustrate the trend and fluctuations in the closing prices, providing a visual insight into the stock's historical performance.

# %%
fig = px.line(df, x='datetime', y='close', title='HINDALCO - Close Prices')  # creating a figure using px.line
display(fig)  # showing figure in output
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="28fb48a9-471f-434c-a7d5-e5ea08a1345b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28fb48a9-471f-434c-a7d5-e5ea08a1345b")) {                    Plotly.newPlot(                        "28fb48a9-471f-434c-a7d5-e5ea08a1345b",                        [{"hovertemplate":"datetime=%{x}\u003cbr\u003eclose=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2014-01-24T00:00:00","2014-01-27T00:00:00","2014-01-28T00:00:00","2014-01-29T00:00:00","2014-01-30T00:00:00","2014-01-31T00:00:00","2014-02-03T00:00:00","2014-02-04T00:00:00","2014-02-05T00:00:00","2014-02-06T00:00:00","2014-02-07T00:00:00","2014-02-10T00:00:00","2014-02-11T00:00:00","2014-02-12T00:00:00","2014-02-13T00:00:00","2014-02-14T00:00:00","2014-02-17T00:00:00","2014-02-18T00:00:00","2014-02-19T00:00:00","2014-02-20T00:00:00","2014-02-21T00:00:00","2014-02-24T00:00:00","2014-02-25T00:00:00","2014-02-26T00:00:00","2014-02-28T00:00:00","2014-03-03T00:00:00","2014-03-04T00:00:00","2014-03-05T00:00:00","2014-03-06T00:00:00","2014-03-07T00:00:00","2014-03-10T00:00:00","2014-03-11T00:00:00","2014-03-12T00:00:00","2014-03-13T00:00:00","2014-03-14T00:00:00","2014-03-18T00:00:00","2014-03-19T00:00:00","2014-03-20T00:00:00","2014-03-21T00:00:00","2014-03-22T00:00:00","2014-03-24T00:00:00","2014-03-25T00:00:00","2014-03-26T00:00:00","2014-03-27T00:00:00","2014-03-28T00:00:00","2014-03-31T00:00:00","2014-04-01T00:00:00","2014-04-02T00:00:00","2014-04-03T00:00:00","2014-04-04T00:00:00","2014-04-07T00:00:00","2014-04-09T00:00:00","2014-04-10T00:00:00","2014-04-11T00:00:00","2014-04-15T00:00:00","2014-04-16T00:00:00","2014-04-17T00:00:00","2014-04-21T00:00:00","2014-04-22T00:00:00","2014-04-23T00:00:00","2014-04-25T00:00:00","2014-04-28T00:00:00","2014-04-29T00:00:00","2014-04-30T00:00:00","2014-05-02T00:00:00","2014-05-05T00:00:00","2014-05-06T00:00:00","2014-05-07T00:00:00","2014-05-08T00:00:00","2014-05-09T00:00:00","2014-05-12T00:00:00","2014-05-13T00:00:00","2014-05-14T00:00:00","2014-05-15T00:00:00","2014-05-16T00:00:00","2014-05-19T00:00:00","2014-05-20T00:00:00","2014-05-21T00:00:00","2014-05-22T00:00:00","2014-05-23T00:00:00","2014-05-26T00:00:00","2014-05-27T00:00:00","2014-05-28T00:00:00","2014-05-29T00:00:00","2014-05-30T00:00:00","2014-06-02T00:00:00","2014-06-03T00:00:00","2014-06-04T00:00:00","2014-06-05T00:00:00","2014-06-06T00:00:00","2014-06-09T00:00:00","2014-06-10T00:00:00","2014-06-11T00:00:00","2014-06-12T00:00:00","2014-06-13T00:00:00","2014-06-16T00:00:00","2014-06-17T00:00:00","2014-06-18T00:00:00","2014-06-19T00:00:00","2014-06-20T00:00:00","2014-06-23T00:00:00","2014-06-24T00:00:00","2014-06-25T00:00:00","2014-06-26T00:00:00","2014-06-27T00:00:00","2014-06-30T00:00:00","2014-07-01T00:00:00","2014-07-02T00:00:00","2014-07-03T00:00:00","2014-07-04T00:00:00","2014-07-07T00:00:00","2014-07-08T00:00:00","2014-07-09T00:00:00","2014-07-10T00:00:00","2014-07-11T00:00:00","2014-07-14T00:00:00","2014-07-15T00:00:00","2014-07-16T00:00:00","2014-07-17T00:00:00","2014-07-18T00:00:00","2014-07-21T00:00:00","2014-07-22T00:00:00","2014-07-23T00:00:00","2014-07-24T00:00:00","2014-07-25T00:00:00","2014-07-28T00:00:00","2014-07-30T00:00:00","2014-07-31T00:00:00","2014-08-01T00:00:00","2014-08-04T00:00:00","2014-08-05T00:00:00","2014-08-06T00:00:00","2014-08-07T00:00:00","2014-08-08T00:00:00","2014-08-11T00:00:00","2014-08-12T00:00:00","2014-08-13T00:00:00","2014-08-14T00:00:00","2014-08-18T00:00:00","2014-08-19T00:00:00","2014-08-20T00:00:00","2014-08-21T00:00:00","2014-08-22T00:00:00","2014-08-25T00:00:00","2014-08-26T00:00:00","2014-08-27T ...

# %% [markdown]
# # Calculating RSI Indicator
#
# The code calculates and visualizes the Relative Strength Index (RSI) for a financial dataset. RSI is a momentum oscillator that measures the speed and change of price movements. The formula involves calculating the ratio of average gains to average losses over a specified period (in this case, 14 days). The resulting RSI values, ranging from 0 to 100, are then plotted over time, providing insights into potential overbought and oversold market conditions. The added horizontal lines at levels 70 and 30 on the plot represent commonly observed thresholds, aiding in the interpretation of RSI trends.

# %%
# setting the RSI Period
rsi_period = 14

# to calculate RSI, we first need to calculate the exponential weighted aveage gain and loss during the period
df['gain'] = (df['close'] - df['open']).apply(lambda x: x if x > 0 else 0)
df['loss'] = (df['close'] - df['open']).apply(lambda x: -x if x < 0 else 0)

# here we use the same formula to calculate Exponential Moving Average
df['ema_gain'] = df['gain'].ewm(span=rsi_period, min_periods=rsi_period).mean()
df['ema_loss'] = df['loss'].ewm(span=rsi_period, min_periods=rsi_period).mean()

# the Relative Strength is the ratio between the exponential avg gain divided by the exponential avg loss
df['rs'] = df['ema_gain'] / df['ema_loss']

# the RSI is calculated based on the Relative Strength using the following formula
df['rsi_14'] = 100 - (100 / (df['rs'] + 1))

# displaying the results
display(df[['datetime', 'rsi_14', 'rs', 'ema_gain', 'ema_loss']])
# plotting the RSI
fig_rsi = px.line(df, x='datetime', y='rsi_14', title='RSI Indicator')

# RSI commonly uses oversold and overbought levels, usually at 70 and 30
overbought_level = 70
oversold_level = 30

# adding oversold and overbought levels to the plot
fig_rsi.add_hline(y=overbought_level, opacity=0.5, line_dash="dash", annotation_text="Overbought", annotation_position="bottom right")
fig_rsi.add_hline(y=oversold_level, opacity=0.5, line_dash="dash", annotation_text="Oversold", annotation_position="top right")

# showing the RSI Figure
fig_rsi.show()
# Out:
#        datetime     rsi_14        rs  ema_gain  ema_loss
# 0    2014-01-24        NaN       NaN       NaN       NaN
# 1    2014-01-27        NaN       NaN       NaN       NaN
# 2    2014-01-28        NaN       NaN       NaN       NaN
# 3    2014-01-29        NaN       NaN       NaN       NaN
# 4    2014-01-30        NaN       NaN       NaN       NaN
# ...         ...        ...       ...       ...       ...
# 1210 2018-12-21  65.353109  1.886262  1.423241  0.754530
# 1211 2018-12-24  45.559387  0.836864  1.233475  1.473926
# 1212 2018-12-26  57.130519  1.332662  1.702345  1.277402
# 1213 2018-12-27  54.864374  1.215545  1.475366  1.213749
# 1214 2018-12-28  60.512188  1.532427  1.611984  1.051916
#
# [1215 rows x 5 columns]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e5ce1b4e-81e3-4159-9040-6f1ee737b7f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e5ce1b4e-81e3-4159-9040-6f1ee737b7f0")) {                    Plotly.newPlot(                        "e5ce1b4e-81e3-4159-9040-6f1ee737b7f0",                        [{"hovertemplate":"datetime=%{x}\u003cbr\u003ersi_14=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2014-01-24T00:00:00","2014-01-27T00:00:00","2014-01-28T00:00:00","2014-01-29T00:00:00","2014-01-30T00:00:00","2014-01-31T00:00:00","2014-02-03T00:00:00","2014-02-04T00:00:00","2014-02-05T00:00:00","2014-02-06T00:00:00","2014-02-07T00:00:00","2014-02-10T00:00:00","2014-02-11T00:00:00","2014-02-12T00:00:00","2014-02-13T00:00:00","2014-02-14T00:00:00","2014-02-17T00:00:00","2014-02-18T00:00:00","2014-02-19T00:00:00","2014-02-20T00:00:00","2014-02-21T00:00:00","2014-02-24T00:00:00","2014-02-25T00:00:00","2014-02-26T00:00:00","2014-02-28T00:00:00","2014-03-03T00:00:00","2014-03-04T00:00:00","2014-03-05T00:00:00","2014-03-06T00:00:00","2014-03-07T00:00:00","2014-03-10T00:00:00","2014-03-11T00:00:00","2014-03-12T00:00:00","2014-03-13T00:00:00","2014-03-14T00:00:00","2014-03-18T00:00:00","2014-03-19T00:00:00","2014-03-20T00:00:00","2014-03-21T00:00:00","2014-03-22T00:00:00","2014-03-24T00:00:00","2014-03-25T00:00:00","2014-03-26T00:00:00","2014-03-27T00:00:00","2014-03-28T00:00:00","2014-03-31T00:00:00","2014-04-01T00:00:00","2014-04-02T00:00:00","2014-04-03T00:00:00","2014-04-04T00:00:00","2014-04-07T00:00:00","2014-04-09T00:00:00","2014-04-10T00:00:00","2014-04-11T00:00:00","2014-04-15T00:00:00","2014-04-16T00:00:00","2014-04-17T00:00:00","2014-04-21T00:00:00","2014-04-22T00:00:00","2014-04-23T00:00:00","2014-04-25T00:00:00","2014-04-28T00:00:00","2014-04-29T00:00:00","2014-04-30T00:00:00","2014-05-02T00:00:00","2014-05-05T00:00:00","2014-05-06T00:00:00","2014-05-07T00:00:00","2014-05-08T00:00:00","2014-05-09T00:00:00","2014-05-12T00:00:00","2014-05-13T00:00:00","2014-05-14T00:00:00","2014-05-15T00:00:00","2014-05-16T00:00:00","2014-05-19T00:00:00","2014-05-20T00:00:00","2014-05-21T00:00:00","2014-05-22T00:00:00","2014-05-23T00:00:00","2014-05-26T00:00:00","2014-05-27T00:00:00","2014-05-28T00:00:00","2014-05-29T00:00:00","2014-05-30T00:00:00","2014-06-02T00:00:00","2014-06-03T00:00:00","2014-06-04T00:00:00","2014-06-05T00:00:00","2014-06-06T00:00:00","2014-06-09T00:00:00","2014-06-10T00:00:00","2014-06-11T00:00:00","2014-06-12T00:00:00","2014-06-13T00:00:00","2014-06-16T00:00:00","2014-06-17T00:00:00","2014-06-18T00:00:00","2014-06-19T00:00:00","2014-06-20T00:00:00","2014-06-23T00:00:00","2014-06-24T00:00:00","2014-06-25T00:00:00","2014-06-26T00:00:00","2014-06-27T00:00:00","2014-06-30T00:00:00","2014-07-01T00:00:00","2014-07-02T00:00:00","2014-07-03T00:00:00","2014-07-04T00:00:00","2014-07-07T00:00:00","2014-07-08T00:00:00","2014-07-09T00:00:00","2014-07-10T00:00:00","2014-07-11T00:00:00","2014-07-14T00:00:00","2014-07-15T00:00:00","2014-07-16T00:00:00","2014-07-17T00:00:00","2014-07-18T00:00:00","2014-07-21T00:00:00","2014-07-22T00:00:00","2014-07-23T00:00:00","2014-07-24T00:00:00","2014-07-25T00:00:00","2014-07-28T00:00:00","2014-07-30T00:00:00","2014-07-31T00:00:00","2014-08-01T00:00:00","2014-08-04T00:00:00","2014-08-05T00:00:00","2014-08-06T00:00:00","2014-08-07T00:00:00","2014-08-08T00:00:00","2014-08-11T00:00:00","2014-08-12T00:00:00","2014-08-13T00:00:00","2014-08-14T00:00:00","2014-08-18T00:00:00","2014-08-19T00:00:00","2014-08-20T00:00:00","2014-08-21T00:00:00","2014-08-22T00:00:00","2014-08-25T00:00:00","2014-08-26T00:00:00","2014-08-27 ...

# %% [markdown]
# # Calculating ATR Indicator
# ATR measures the average range for each period and is therefore a good volatility indicator. After entering a trade, we will set take profit and stop loss to 2 ATR each. Traders might use this in combination with the RSI indicator to get a more comprehensive view of market conditions.

# %%
# defining the ATR period to 14
atr_period = 14

# calculating the range of each candle
df['range'] = df['high'] - df['low']

# calculating the average value of ranges
df['atr_14'] = df['range'].rolling(atr_period).mean()

# displaying the results
display(df[['datetime', 'atr_14']])

# plotting the ATR Indicator
fig_atr = px.line(df, x='datetime', y='atr_14', title='ATR Indicator')

# displaying the ATR Figure
fig_atr.show()
# Out:
#        datetime    atr_14
# 0    2014-01-24       NaN
# 1    2014-01-27       NaN
# 2    2014-01-28       NaN
# 3    2014-01-29       NaN
# 4    2014-01-30       NaN
# ...         ...       ...
# 1210 2018-12-21  5.896429
# 1211 2018-12-24  5.921429
# 1212 2018-12-26  5.692857
# 1213 2018-12-27  5.478571
# 1214 2018-12-28  5.492857
#
# [1215 rows x 2 columns]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="785eced2-5968-42af-938b-f6e76bc93711" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("785eced2-5968-42af-938b-f6e76bc93711")) {                    Plotly.newPlot(                        "785eced2-5968-42af-938b-f6e76bc93711",                        [{"hovertemplate":"datetime=%{x}\u003cbr\u003eatr_14=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2014-01-24T00:00:00","2014-01-27T00:00:00","2014-01-28T00:00:00","2014-01-29T00:00:00","2014-01-30T00:00:00","2014-01-31T00:00:00","2014-02-03T00:00:00","2014-02-04T00:00:00","2014-02-05T00:00:00","2014-02-06T00:00:00","2014-02-07T00:00:00","2014-02-10T00:00:00","2014-02-11T00:00:00","2014-02-12T00:00:00","2014-02-13T00:00:00","2014-02-14T00:00:00","2014-02-17T00:00:00","2014-02-18T00:00:00","2014-02-19T00:00:00","2014-02-20T00:00:00","2014-02-21T00:00:00","2014-02-24T00:00:00","2014-02-25T00:00:00","2014-02-26T00:00:00","2014-02-28T00:00:00","2014-03-03T00:00:00","2014-03-04T00:00:00","2014-03-05T00:00:00","2014-03-06T00:00:00","2014-03-07T00:00:00","2014-03-10T00:00:00","2014-03-11T00:00:00","2014-03-12T00:00:00","2014-03-13T00:00:00","2014-03-14T00:00:00","2014-03-18T00:00:00","2014-03-19T00:00:00","2014-03-20T00:00:00","2014-03-21T00:00:00","2014-03-22T00:00:00","2014-03-24T00:00:00","2014-03-25T00:00:00","2014-03-26T00:00:00","2014-03-27T00:00:00","2014-03-28T00:00:00","2014-03-31T00:00:00","2014-04-01T00:00:00","2014-04-02T00:00:00","2014-04-03T00:00:00","2014-04-04T00:00:00","2014-04-07T00:00:00","2014-04-09T00:00:00","2014-04-10T00:00:00","2014-04-11T00:00:00","2014-04-15T00:00:00","2014-04-16T00:00:00","2014-04-17T00:00:00","2014-04-21T00:00:00","2014-04-22T00:00:00","2014-04-23T00:00:00","2014-04-25T00:00:00","2014-04-28T00:00:00","2014-04-29T00:00:00","2014-04-30T00:00:00","2014-05-02T00:00:00","2014-05-05T00:00:00","2014-05-06T00:00:00","2014-05-07T00:00:00","2014-05-08T00:00:00","2014-05-09T00:00:00","2014-05-12T00:00:00","2014-05-13T00:00:00","2014-05-14T00:00:00","2014-05-15T00:00:00","2014-05-16T00:00:00","2014-05-19T00:00:00","2014-05-20T00:00:00","2014-05-21T00:00:00","2014-05-22T00:00:00","2014-05-23T00:00:00","2014-05-26T00:00:00","2014-05-27T00:00:00","2014-05-28T00:00:00","2014-05-29T00:00:00","2014-05-30T00:00:00","2014-06-02T00:00:00","2014-06-03T00:00:00","2014-06-04T00:00:00","2014-06-05T00:00:00","2014-06-06T00:00:00","2014-06-09T00:00:00","2014-06-10T00:00:00","2014-06-11T00:00:00","2014-06-12T00:00:00","2014-06-13T00:00:00","2014-06-16T00:00:00","2014-06-17T00:00:00","2014-06-18T00:00:00","2014-06-19T00:00:00","2014-06-20T00:00:00","2014-06-23T00:00:00","2014-06-24T00:00:00","2014-06-25T00:00:00","2014-06-26T00:00:00","2014-06-27T00:00:00","2014-06-30T00:00:00","2014-07-01T00:00:00","2014-07-02T00:00:00","2014-07-03T00:00:00","2014-07-04T00:00:00","2014-07-07T00:00:00","2014-07-08T00:00:00","2014-07-09T00:00:00","2014-07-10T00:00:00","2014-07-11T00:00:00","2014-07-14T00:00:00","2014-07-15T00:00:00","2014-07-16T00:00:00","2014-07-17T00:00:00","2014-07-18T00:00:00","2014-07-21T00:00:00","2014-07-22T00:00:00","2014-07-23T00:00:00","2014-07-24T00:00:00","2014-07-25T00:00:00","2014-07-28T00:00:00","2014-07-30T00:00:00","2014-07-31T00:00:00","2014-08-01T00:00:00","2014-08-04T00:00:00","2014-08-05T00:00:00","2014-08-06T00:00:00","2014-08-07T00:00:00","2014-08-08T00:00:00","2014-08-11T00:00:00","2014-08-12T00:00:00","2014-08-13T00:00:00","2014-08-14T00:00:00","2014-08-18T00:00:00","2014-08-19T00:00:00","2014-08-20T00:00:00","2014-08-21T00:00:00","2014-08-22T00:00:00","2014-08-25T00:00:00","2014-08-26T00:00:00","2014-08-27 ...

# %% [markdown]
# # Basic Trading Strategy Backtest
#
# In this segment, we conduct a backtest for a fundamental trading strategy, specifically focusing on the Relative Strength Index (RSI), using Python. The code introduces two pivotal classes: Position and Strategy. The Position class adeptly encapsulates trade intricacies, encompassing details such as open and close conditions, profit, and status. The overarching orchestration of the backtest lies within the Strategy class, where the provided financial data is leveraged to enact the intricacies of the trading logic.
#
# The procedural workflow involves iteratively traversing the financial dataset, initiating positions predicated on RSI thresholds, and systematically closing them in adherence to stop-loss or take-profit conditions. The consequential backtest results are elegantly synthesized into a DataFrame, unveiling a comprehensive snapshot of each position's performance, cumulative profit and loss, and other pertinent particulars. This methodically structured approach not only provides a robust evaluation of the RSI-based strategy but also sets the stage for the systematic scrutiny of diverse trading strategies applied to historical datasets.

# %% [markdown]
# ## Importing classes for Backtesting

# %%
# class Position contains data about trades opened/closed during the backtest
class Position:
    def __init__(self, open_datetime, open_price, order_type, volume, sl, tp):
        self.open_datetime = open_datetime
        self.open_price = open_price
        self.order_type = order_type
        self.volume = volume
        self.sl = sl
        self.tp = tp
        self.close_datetime = None
        self.close_price = None
        self.profit = None
        self.status = 'open'

    def close_position(self, close_datetime, close_price):
        self.close_datetime = close_datetime
        self.close_price = close_price
        self.profit = (self.close_price - self.open_price) * self.volume if self.order_type == 'buy' \
            else (self.open_price - self.close_price) * self.volume
        self.status = 'closed'

    def _asdict(self):
        return {
            'open_datetime': self.open_datetime,
            'open_price': self.open_price,
            'order_type': self.order_type,
            'volume': self.volume,
            'sl': self.sl,
            'tp': self.tp,
            'close_datetime': self.close_datetime,
            'close_price': self.close_price,
            'profit': self.profit,
            'status': self.status,
        }


# class Strategy defines trading logic and evaluates the backtest based on opened/closed positions
class Strategy:
    def __init__(self, df, starting_balance):
        self.starting_balance = starting_balance
        self.positions = []
        self.data = df

    # return backtest result
    def get_positions_df(self):
        df = pd.DataFrame([position._asdict() for position in self.positions])
        df['pnl'] = df['profit'].cumsum() + self.starting_balance
        return df

    # add Position class to the list
    def add_position(self, position):
        self.positions.append(position)
        return True

    # close positions when stop loss or take profit is reached
    def close_tp_sl(self, data):
        for pos in self.positions:
            if pos.status == 'open':
                if (pos.sl >= data['close'] and pos.order_type == 'buy'):
                    pos.close_position(data['datetime'], pos.sl)
                elif (pos.sl <= data['close'] and pos.order_type == 'sell'):
                    pos.close_position(data['datetime'], pos.sl)
                elif (pos.tp <= data['close'] and pos.order_type == 'buy'):
                    pos.close_position(data['datetime'], pos.tp)
                elif (pos.tp >= data['close'] and pos.order_type == 'sell'):
                    pos.close_position(data['datetime'], pos.tp)

    # check for open positions
    def has_open_positions(self):
        for pos in self.positions:
            if pos.status == 'open':
                return True
        return False

    # strategy logic how positions should be opened/closed
    def logic(self, data):
        # if no position is open
        if not self.has_open_positions():
            # if RSI is less than 30 -> BUY
            if data['rsi_14'] < 30:
                # Position variables
                open_datetime = data['datetime']
                open_price = data['close']
                order_type = 'buy'
                volume = data['volume']
                sl = open_price - 2 * data['atr_14']
                tp = open_price + 2 * data['atr_14']
                self.add_position(Position(open_datetime, open_price, order_type, volume, sl, tp))

            # if RSI is greater than 70 -> SELL
            elif data['rsi_14'] > 70:
                # Position variables
                open_datetime = data['datetime']
                open_price = data['close']
                order_type = 'sell'
                volume = data['volume']
                sl = open_price + 2 * data['atr_14']
                tp = open_price - 2 * data['atr_14']
                self.add_position(Position(open_datetime, open_price, order_type, volume, sl, tp))

    # logic
    def run(self):
        # data represents a moment in time while iterating through the backtest
        for i, data in self.data.iterrows():
            # close positions when stop loss or take profit is reached
            self.close_tp_sl(data)
            # strategy logic
            self.logic(data)

        return self.get_positions_df()

# %% [markdown]
# ## Preparing Data for Backtest

# %%
backtest_df = df[14:]  # removing NaN values
backtest_df
# Out:
#        datetime   close    high     low    open    volume instrument  gain  \
# 14   2014-02-13  100.20  104.55   99.75  103.90  12652556   HINDALCO  0.00
# 15   2014-02-14   99.90  101.00   97.85  100.75   6390793   HINDALCO  0.00
# 16   2014-02-17   98.50  100.75   97.65  100.00   6870442   HINDALCO  0.00
# 17   2014-02-18   99.30  100.50   97.75   98.70   8475360   HINDALCO  0.60
# 18   2014-02-19   98.85  100.10   98.40   99.60   4582897   HINDALCO  0.00
# ...         ...     ...     ...     ...     ...       ...        ...   ...
# 1210 2018-12-21  224.00  227.45  221.80  224.25   6933691   HINDALCO  0.00
# 1211 2018-12-24  217.85  224.00  216.95  224.00   4667022   HINDALCO  0.00
# 1212 2018-12-26  218.60  219.80  212.90  213.85   6554865   HINDALCO  4.75
# 1213 2018-12-27  220.60  223.90  219.60  221.40   7947144   HINDALCO  0.00
# 1214 2018-12-28  223.50  226.05  221.00  221.00   5074920   HINDALCO  2.50
#
#       loss  ema_gain  ema_loss        rs     rsi_14  range    atr_14
# 14    3.70  0.421367  1.490715  0.282661  22.037063   4.80  3.642857
# 15    0.85  0.358851  1.395656  0.257120  20.453103   3.15  3.625000
# 16    1.50  0.306399  1.410908  0.217165  17.841842   3.10  3.471429
# 17    0.00  0.348770  1.207293  0.288886  22.413614   2.75  3.410714
# 18    0.75  0.298984  1.142016  0.261804  20.748377   1.70  3.310714
# ...    ...       ...       ...       ...        ...    ...       ...
# 1210  0.25  1.423241  0.754530  1.886262  65.353109   5.65  5.896429
# 1211  6.15  1.233475  1.473926  0.836864  45.559387   7.05  5.921429
# 1212  0.00  1.702345  1.277402  1.332662  57.130519   6.90  5.692857
# 1213  0.80  1.475366  1.213749  1.215545  54.864374   4.30  5.478571
# 1214  0.00  1.611984  1.051916  1.532427  60.512188   5.05  5.492857
#
# [1201 rows x 15 columns]

# %% [markdown]
# ## Running the Backtest

# %%
rsi_strategy = Strategy(backtest_df, starting_balance=100000)
backtest_results = rsi_strategy.run()
backtest_results
# Out:
#    open_datetime  open_price order_type    volume          sl          tp  \
# 0     2014-02-13      100.20        buy  12652556   92.914286  107.485714
# 1     2014-03-04      113.60       sell  16427565  120.064286  107.135714
# 2     2014-03-06      120.80       sell  16609108  127.857143  113.742857
# 3     2014-03-28      130.90       sell   9719662  138.992857  122.807143
# 4     2014-03-31      141.75       sell  27873616  150.728571  132.771429
# 5     2014-05-21      159.70       sell  13573762  173.850000  145.550000
# 6     2014-07-24      198.00       sell  14784601  214.664286  181.335714
# 7     2014-08-25      164.85        buy  18698120  149.971429  179.728571
# 8     2014-09-25      149.15        buy  31086655  134.157143  164.142857
# 9     2014-11-26      169.15       sell   7594843  180.292857  158.007143
# 10    2014-12-09      154.45        buy   7678563  142.200000  166.700000
# 11    2015-01-14      142.15        buy  13580758  132.400000  151.900000
# 12    2015-02-26      149.75        buy   9010829  139.178571  160.321429
# 13    2015-03-10      138.05        buy   6588296  125.928571  150.171429
# 14    2015-06-02      123.25        buy   4980345  115.707143  130.792857
# 15    2015-06-15      114.30        buy   4287348  107.021429  121.578571
# 16    2015-06-24      117.25        buy   3604713  110.685714  123.814286
# 17    2015-07-03      110.60        buy   4606491  104.428571  116.771429
# 18    2015-07-08      101.85        buy  12611248   95.421429  108.278571
# 19    2015-08-12       95.90        buy  11715218   88.071429  103.728571
# 20    2015-08-19       86.15        buy   9032174   77.085714   95.214286
# 21    2015-09-01       75.95        buy   9754819   66.664286   85.235714
# 22    2015-10-12       88.65       sell  26948602   96.085714   81.214286
# 23    2015-11-05       81.05        buy   4001045   75.892857   86.207143
# 24    2015-11-23       74.25        buy  11048526   68.235714   80.264286
# 25    2016-01-07       76.65        buy   8098318   71.514286   81.785714
# 26    2016-01-18       71.20        buy   6814262   64.785714   77.614286
# 27    2016-02-11       63.70        buy   7915911   57.785714   69.614286
# 28    2016-03-08       83.15       sell  19055239   90.035714   76.264286
# 29    2016-03-23       91.30       sell  22685606   98.100000   84.500000
# 30    2016-04-13       96.30       sell  18201767  104.450000   88.150000
# 31    2016-05-19       87.05        buy  10822516   79.992857   94.107143
# 32    2016-06-09      110.90       sell  16009358  117.485714  104.314286
# 33    2016-06-16      119.05       sell  19649978  126.528571  111.571429
# 34    2016-07-12      135.25       sell  26490373  142.435714  128.064286
# 35    2016-08-08      149.15       sell  20168915  157.907143  140.392857
# 36    2016-09-12      140.85        buy  16165924  131.378571  150.321429
# 37    2016-10-27      148.30        buy   8386282  139.571429  157.028571
# 38    2016-11-03      162.80       sell  26147206  172.114286  153.485714
# 39    2016-11-10      175.75       sell  16275443  188.585714  162.914286
# 40    2016-12-22      161.25        buy   9593033  150.857143  171.642857
# 41    2017-01-25      190.75       sell  21241955  203.428571  178.071429
# 42    2017-07-19      213.45       sell  13700281  223.321429  203.578571
# 43    2017-08-01      225.75       sell  10837725  236.114286  215.385714
# 44    2017-08-09      239.45       sell  12844802  252.107143  226.792857
# 45    2017-09-22      230.90        buy  14454217  216.514286  245.285714
# 46    2017-10-12      264.45       sell  30320448  279.421429  249.478571
# 47    2017-11-29      246.90        buy   5285364  233.521429  260.278571
# 48    2017-12-06      232.10        buy   7402990  218.864286  245.335714
# 49    2017-12-20      258.35       sell  15519081  272.764286  243.935714
# 50    2017-12-28      275.25       sell  22938436  289.364286  261.135714
# 51    2018-01-16      260.55        buy   8447591  245.935714  275.164286
# 52    2018-03-06      225.85        buy  12488311  209.585714  242.114286
# 53    2018-04-19      264.75       sell  37033062  280.057143  249.442857
# 54    2018-05-21      228.25        buy   8159685  212.664286  243.835714
# 55    2018-06-21      222.30        buy   6019694  208.514286  236.085714
# 56    2018-07-19      197.60        buy  33211007  180.000000  215.200000
# 57    2018-09-28      229.65        buy  11588117  208.450000  250.850000
#
#    close_datetime  close_price        profit  status           pnl
# 0      2014-03-04   107.485714  9.218291e+07  closed  9.228291e+07
# 1      2014-03-06   120.064286 -1.061925e+08  closed -1.390957e+07
# 2      2014-03-28   127.857143 -1.172128e+08  closed -1.311224e+08
# 3      2014-03-31   138.992857 -7.865984e+07  closed -2.097822e+08
# 4      2014-05-02   132.771429  2.502653e+08  closed  4.048300e+07
# 5      2014-07-01   173.850000 -1.920687e+08  closed -1.515857e+08
# 6      2014-08-13   181.335714  2.463748e+08  closed  9.478909e+07
# 7      2014-09-25   149.971429 -2.782013e+08  closed -1.834122e+08
# 8      2014-11-24   164.142857  4.660778e+08  closed  2.826655e+08
# 9      2014-12-09   158.007143  8.462825e+07  closed  3.672938e+08
# 10     2015-01-14   142.200000 -9.406240e+07  closed  2.732314e+08
# 11     2015-02-04   151.900000  1.324124e+08  closed  4.056438e+08
# 12     2015-03-10   139.178571 -9.525734e+07  closed  3.103865e+08
# 13     2015-06-02   125.928571 -7.985956e+07  closed  2.305269e+08
# 14     2015-06-15   115.707143 -3.756603e+07  closed  1.929609e+08
# 15     2015-06-23   121.578571  3.120577e+07  closed  2.241666e+08
# 16     2015-07-03   110.685714 -2.366237e+07  closed  2.005043e+08
# 17     2015-07-08   104.428571 -2.842863e+07  closed  1.720756e+08
# 18     2015-07-20   108.278571  8.107231e+07  closed  2.531479e+08
# 19     2015-08-19    88.071429 -9.171342e+07  closed  1.614345e+08
# 20     2015-09-01    77.085714 -8.187021e+07  closed  7.956432e+07
# 21     2015-10-12    85.235714  9.058046e+07  closed  1.701448e+08
# 22     2015-11-02    81.214286  2.003821e+08  closed  3.705269e+08
# 23     2015-11-23    75.892857 -2.063396e+07  closed  3.498929e+08
# 24     2015-12-02    80.264286  6.644899e+07  closed  4.163419e+08
# 25     2016-01-18    71.514286 -4.159065e+07  closed  3.747513e+08
# 26     2016-02-11    64.785714 -4.370862e+07  closed  3.310426e+08
# 27     2016-03-01    69.614286  4.681696e+07  closed  3.778596e+08
# 28     2016-03-23    90.035714 -1.312089e+08  closed  2.466507e+08
# 29     2016-03-28    84.500000  1.542621e+08  closed  4.009128e+08
# 30     2016-05-19    88.150000  1.483444e+08  closed  5.492572e+08
# 31     2016-05-30    94.107143  7.637604e+07  closed  6.256332e+08
# 32     2016-06-16   117.485714 -1.054331e+08  closed  5.202002e+08
# 33     2016-07-07   126.528571 -1.469538e+08  closed  3.732464e+08
# 34     2016-08-05   142.435714 -1.903523e+08  closed  1.828942e+08
# 35     2016-08-19   157.907143 -1.766221e+08  closed  6.272098e+06
# 36     2016-09-22   150.321429  1.531144e+08  closed  1.593865e+08
# 37     2016-11-03   157.028571  7.320026e+07  closed  2.325868e+08
# 38     2016-11-10   172.114286 -2.435425e+08  closed -1.095579e+07
# 39     2016-11-16   162.914286  2.089069e+08  closed  1.979511e+08
# 40     2017-01-11   171.642857  9.969902e+07  closed  2.976502e+08
# 41     2017-07-13   203.428571 -2.693176e+08  closed  2.833252e+07
# 42     2017-08-01   223.321429 -1.352413e+08  closed -1.069088e+08
# 43     2017-08-09   236.114286 -1.123253e+08  closed -2.192341e+08
# 44     2017-08-11   226.792857  1.625785e+08  closed -5.665561e+07
# 45     2017-10-06   245.285714  2.079342e+08  closed  1.512786e+08
# 46     2017-11-29   249.478571  4.539404e+08  closed  6.052190e+08
# 47     2017-12-06   233.521429 -7.071062e+07  closed  5.345084e+08
# 48     2017-12-18   245.335714  9.798386e+07  closed  6.324923e+08
# 49     2017-12-28   272.764286 -2.236965e+08  closed  4.087958e+08
# 50     2018-01-16   261.135714  3.237596e+08  closed  7.325555e+08
# 51     2018-02-06   245.935714 -1.234555e+08  closed  6.091000e+08
# 52     2018-03-23   209.585714 -2.031135e+08  closed  4.059865e+08
# 53     2018-04-24   249.442857  5.668704e+08  closed  9.728569e+08
# 54     2018-05-25   243.835714  1.271745e+08  closed  1.100031e+09
# 55     2018-07-19   208.514286 -8.298578e+07  closed  1.017046e+09
# 56     2018-08-06   215.200000  5.845137e+08  closed  1.601559e+09
# 57     2018-10-03   250.850000  2.456681e+08  closed  1.847227e+09

# %% [markdown]
# ## Visualizing the Backtest

# %%
# Filter closed positions
backtest_result = backtest_results[backtest_results['status'] == 'closed']

# Visualization Setup
fig_backtest = px.line(df, x='datetime', y=['close'], title='RSI Strategy - Trades')

# Adding Trades to the Plot
for i, position in backtest_result.iterrows():
    if position.status == 'closed':
        fig_backtest.add_shape(type="line",
            x0=position.open_datetime, y0=position.open_price, x1=position.close_datetime, y1=position.close_price,
            line=dict(
                color="green" if position.profit >= 0 else "red",
                width=3)
            )

# Display the Plot
fig_backtest.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="470f1b4e-5f57-42c1-be81-7beb736d9357" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("470f1b4e-5f57-42c1-be81-7beb736d9357")) {                    Plotly.newPlot(                        "470f1b4e-5f57-42c1-be81-7beb736d9357",                        [{"hovertemplate":"variable=close\u003cbr\u003edatetime=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"close","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"close","showlegend":true,"x":["2014-01-24T00:00:00","2014-01-27T00:00:00","2014-01-28T00:00:00","2014-01-29T00:00:00","2014-01-30T00:00:00","2014-01-31T00:00:00","2014-02-03T00:00:00","2014-02-04T00:00:00","2014-02-05T00:00:00","2014-02-06T00:00:00","2014-02-07T00:00:00","2014-02-10T00:00:00","2014-02-11T00:00:00","2014-02-12T00:00:00","2014-02-13T00:00:00","2014-02-14T00:00:00","2014-02-17T00:00:00","2014-02-18T00:00:00","2014-02-19T00:00:00","2014-02-20T00:00:00","2014-02-21T00:00:00","2014-02-24T00:00:00","2014-02-25T00:00:00","2014-02-26T00:00:00","2014-02-28T00:00:00","2014-03-03T00:00:00","2014-03-04T00:00:00","2014-03-05T00:00:00","2014-03-06T00:00:00","2014-03-07T00:00:00","2014-03-10T00:00:00","2014-03-11T00:00:00","2014-03-12T00:00:00","2014-03-13T00:00:00","2014-03-14T00:00:00","2014-03-18T00:00:00","2014-03-19T00:00:00","2014-03-20T00:00:00","2014-03-21T00:00:00","2014-03-22T00:00:00","2014-03-24T00:00:00","2014-03-25T00:00:00","2014-03-26T00:00:00","2014-03-27T00:00:00","2014-03-28T00:00:00","2014-03-31T00:00:00","2014-04-01T00:00:00","2014-04-02T00:00:00","2014-04-03T00:00:00","2014-04-04T00:00:00","2014-04-07T00:00:00","2014-04-09T00:00:00","2014-04-10T00:00:00","2014-04-11T00:00:00","2014-04-15T00:00:00","2014-04-16T00:00:00","2014-04-17T00:00:00","2014-04-21T00:00:00","2014-04-22T00:00:00","2014-04-23T00:00:00","2014-04-25T00:00:00","2014-04-28T00:00:00","2014-04-29T00:00:00","2014-04-30T00:00:00","2014-05-02T00:00:00","2014-05-05T00:00:00","2014-05-06T00:00:00","2014-05-07T00:00:00","2014-05-08T00:00:00","2014-05-09T00:00:00","2014-05-12T00:00:00","2014-05-13T00:00:00","2014-05-14T00:00:00","2014-05-15T00:00:00","2014-05-16T00:00:00","2014-05-19T00:00:00","2014-05-20T00:00:00","2014-05-21T00:00:00","2014-05-22T00:00:00","2014-05-23T00:00:00","2014-05-26T00:00:00","2014-05-27T00:00:00","2014-05-28T00:00:00","2014-05-29T00:00:00","2014-05-30T00:00:00","2014-06-02T00:00:00","2014-06-03T00:00:00","2014-06-04T00:00:00","2014-06-05T00:00:00","2014-06-06T00:00:00","2014-06-09T00:00:00","2014-06-10T00:00:00","2014-06-11T00:00:00","2014-06-12T00:00:00","2014-06-13T00:00:00","2014-06-16T00:00:00","2014-06-17T00:00:00","2014-06-18T00:00:00","2014-06-19T00:00:00","2014-06-20T00:00:00","2014-06-23T00:00:00","2014-06-24T00:00:00","2014-06-25T00:00:00","2014-06-26T00:00:00","2014-06-27T00:00:00","2014-06-30T00:00:00","2014-07-01T00:00:00","2014-07-02T00:00:00","2014-07-03T00:00:00","2014-07-04T00:00:00","2014-07-07T00:00:00","2014-07-08T00:00:00","2014-07-09T00:00:00","2014-07-10T00:00:00","2014-07-11T00:00:00","2014-07-14T00:00:00","2014-07-15T00:00:00","2014-07-16T00:00:00","2014-07-17T00:00:00","2014-07-18T00:00:00","2014-07-21T00:00:00","2014-07-22T00:00:00","2014-07-23T00:00:00","2014-07-24T00:00:00","2014-07-25T00:00:00","2014-07-28T00:00:00","2014-07-30T00:00:00","2014-07-31T00:00:00","2014-08-01T00:00:00","2014-08-04T00:00:00","2014-08-05T00:00:00","2014-08-06T00:00:00","2014-08-07T00:00:00","2014-08-08T00:00:00","2014-08-11T00:00:00","2014-08-12T00:00:00","2014-08-13T00:00:00","2014-08-14T00:00:00","2014-08-18T00:00:00","2014-08-19T00:00:00","2014-08-20T00:00:00","2014-08-21T00:00:00","2014-08-22T00:00:00","2014-08-25T00:00:0 ...

# %% [markdown]
# ## Plotting PnL

# %%
fig_pnl = px.line(backtest_result, x='close_datetime', y='pnl', title='Profit and Loss Over Time')
fig_pnl.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3e67c8c6-955b-4d25-a293-12b9855bb498" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e67c8c6-955b-4d25-a293-12b9855bb498")) {                    Plotly.newPlot(                        "3e67c8c6-955b-4d25-a293-12b9855bb498",                        [{"hovertemplate":"close_datetime=%{x}\u003cbr\u003epnl=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2014-03-04T00:00:00","2014-03-06T00:00:00","2014-03-28T00:00:00","2014-03-31T00:00:00","2014-05-02T00:00:00","2014-07-01T00:00:00","2014-08-13T00:00:00","2014-09-25T00:00:00","2014-11-24T00:00:00","2014-12-09T00:00:00","2015-01-14T00:00:00","2015-02-04T00:00:00","2015-03-10T00:00:00","2015-06-02T00:00:00","2015-06-15T00:00:00","2015-06-23T00:00:00","2015-07-03T00:00:00","2015-07-08T00:00:00","2015-07-20T00:00:00","2015-08-19T00:00:00","2015-09-01T00:00:00","2015-10-12T00:00:00","2015-11-02T00:00:00","2015-11-23T00:00:00","2015-12-02T00:00:00","2016-01-18T00:00:00","2016-02-11T00:00:00","2016-03-01T00:00:00","2016-03-23T00:00:00","2016-03-28T00:00:00","2016-05-19T00:00:00","2016-05-30T00:00:00","2016-06-16T00:00:00","2016-07-07T00:00:00","2016-08-05T00:00:00","2016-08-19T00:00:00","2016-09-22T00:00:00","2016-11-03T00:00:00","2016-11-10T00:00:00","2016-11-16T00:00:00","2017-01-11T00:00:00","2017-07-13T00:00:00","2017-08-01T00:00:00","2017-08-09T00:00:00","2017-08-11T00:00:00","2017-10-06T00:00:00","2017-11-29T00:00:00","2017-12-06T00:00:00","2017-12-18T00:00:00","2017-12-28T00:00:00","2018-01-16T00:00:00","2018-02-06T00:00:00","2018-03-23T00:00:00","2018-04-24T00:00:00","2018-05-25T00:00:00","2018-07-19T00:00:00","2018-08-06T00:00:00","2018-10-03T00:00:00"],"xaxis":"x","y":[92282908.00000007,-13909565.749999821,-131122413.63571398,-209782249.67857125,40483002.55000016,-151585729.7499999,94789085.48571432,-183412228.51428527,282665548.950001,367293799.52142954,273231402.77142954,405643793.27142954,310386458.1285725,230526898.75714397,192960867.9000011,224166636.55714396,200504270.50714394,172075640.3357154,253147948.907144,161434527.9928582,79564322.23571531,170144784.37857252,370526889.2500011,349892928.60714394,416341920.6928583,374751273.25000113,331042649.85000104,377859609.19285816,246650677.79285815,400912798.59285843,549257199.6428585,625633241.1285728,520200183.44285846,373246419.4000013,182894167.70000136,6272097.771429747,159386492.22857243,232586753.68571526,-10955793.628570527,197951142.5928581,297650164.12857234,28332520.378572583,-106908824.92142734,-219234103.31428462,-56655609.42857015,151278626.55714393,605219048.0428579,534508428.2428579,632492288.7428577,408795821.1857149,732555460.7285717,609099952.2571433,405986494.06428623,972856864.5357145,1100031383.6071432,1017045602.0357146,1601559325.2357144,1847227405.6357143],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576 ...
